# %% [markdown]
# # Extracting `HOURLY` data from API and Loading it to DB

# %% [markdown]
# As the purpose of our pipeline is to make Weather Data available for comparison to flights and airports data, in the first step we need to load the weather data in a raw form (JSON) into our database. So in later steps we can transform it to meaningful and useful tables.

# %% [markdown]
# ### General Presteps:

# %% [markdown]
# The Goal of this Notebook is to get raw JSON data for **Hourly** Weather for 3 airport weather stations and load it as it is to our database.
# - Find Station IDs for **defined** airports (we use the same stations as for the daily data)
# - Define the start and end of the period
# - get the API Key from the `.env`

# %% [markdown]
# ### Imports

# %% [markdown]
# we will need the credentials we saved in the `.env` file. We also will need SQLAlchemy and its functions

# %%
# we will need the credentials we saved in the .env file
from dotenv import dotenv_values

# We also will need SQLAlchemy and its functions
from sqlalchemy import create_engine, types
from sqlalchemy.dialects.postgresql import JSON as postgres_json

import pandas as pd

# requests library will make the API calls. 
# the json package will parse the JSON string and convert it to Python data structures
import requests
import json

# with 'datetime' we want to catch the timestamp of the API call. For the actuality reference. 
# and 'time' for slowing down a .bit
from datetime import datetime
import time

# %% [markdown]
# ### Defining Airports andd finding the Station IDs

# %% [markdown]
# For our Pipeline we will use weather data from the weather stations at the 3 highly frequented airports
# - **JFK**: John F. Kennedy Airport
# - **MIA**: Miami International Airport
# - **LAX**: Los Angeles Airport

# %% [markdown]
# To find the Station IDs for the airpors without stressing our API Call limits, we will use the   search option of the **https://meteostat.net/**
#
# Search for the names of the airports above and find the Station IDs

# %%
airport_staids = {
        'MIA': 72202,  
    'MCO': 72205, 
    'TPA': 72211 
                          }

# %% [markdown]
# ### Defining the period

# %% [markdown]
# Our flight Data is from 2024-01-01 until 2024-03-31. For the lectures we will use the same period for the meteostat JSON API.

# %%
period_start = "2017-08-30"  # Added the closing quote
period_end = "2017-09-30"

# %% [markdown]
# ### loading API Key

# %%
# getting API and DB credentials - Alternative 1: dotenv_values()

config = dotenv_values()

api_key = config['X-RapidAPI_Key'] # align the key label with your .env file

# %% [markdown]
# # Part 2: Hourly Station Data

# %% [markdown]
# During your research of the API you might have noticed that the `Hourly Station API` has an additional restriction:

# %% [markdown]
# >#### Hourly data can be queried for a maximum of 30 days per request.
# >https://dev.meteostat.net/api/stations/hourly.html
# >
# >...actually the notation is not exact, we can still get a full month with 31 days. Nobody is perfect.

# %% [markdown]
# ### Objectives -  Hourly Station Data:

# %% [markdown]
# - create a for-loop for the 3 airports with a nested for-loop for monthly start-, end-dates
# - each nested iteration shall generate a **querystring for an API call**
# - define an empty dictionary to collect:
#   - time of the call
#   - airport code
#   - station id
#   - related data
# - make the API calls using the nested for-loops and fill the dictionary
# - create pandas dataframe from the dictionary
# - load the DB credentials from the `.env`
# - create the engine
# - define data types for the postgresql table columns
# - using pandas import the dataframe to the Table in the Schema of the DB

# %% [markdown]
# ### Generating start & end days per month

# %% [markdown]
# We need to create a for-loop iterating over pairs of first and last days of months

# %% [markdown]
# Let's say, we want to cover same 3 months of the flights data: **01/01/2024 - 31/03/2024**

# %%
print(f'period: from {period_start} until {period_end}')
# Out:
# period: from 2017-08-30 until 2017-09-30

# %% [markdown]
# We can use `pd.date_range()` to get first days in a monthly frequence.
# Then using `pd.offsets.MonthEnd()` we get the last days of the month.
# Cool thing is, `pd.offsets.MonthEnd()` actually evaluates whether the month is 31, 30, 29 or 28 day long.

# %% [markdown]
# #### Test: getting the first day of each month

# %%
pd.date_range(start=period_start, end=period_end, freq='MS')
# Out:
# DatetimeIndex(['2017-09-01'], dtype='datetime64[ns]', freq='MS')

# %% [markdown]
# #### Test: getting the last day of a month by adding `+ pd.offsets.MonthEnd()`

# %%
pd.date_range(start=period_start, end=period_end, freq='MS') + pd.offsets.MonthEnd()
# Out:
# DatetimeIndex(['2017-09-30'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# #### let's save it in variables...

# %%
first_days = pd.date_range(start=period_start, end=period_end, freq='MS')
last_days = first_days + pd.offsets.MonthEnd() # see, what we did here? DRY rules! :)

# %% [markdown]
# #### ... and make it lists of strings

# %%
first_days_list = first_days.strftime('%Y-%m-%d').tolist()
last_days_list = last_days.astype(str).tolist()

# %%
print(first_days_list) 
print(last_days_list)
# Out:
# ['2017-09-01']
# ['2017-09-30']

# %% [markdown]
# #### building pairs of (start, end) per month in a list

# %%
monthly_ranges =[]

for start_date, end_date in zip(first_days_list, last_days_list):
    monthly_ranges.append((start_date, end_date))

monthly_ranges

# alternative as list comprehension (less beginner-friendly)
# monthly_ranges = [(start_date, end_date) for start_date, end_date in zip(first_days_list, last_days_list)]
# Out:
# [('2017-09-01', '2017-09-30')]

# %% [markdown]
# ### Test: `simulating` nested for-loops, creating querystring for each airport for each month

# %% [markdown]
# in order not to overstress the API with too many calls at once, we will use `time.sleep(0.34)` at the end of each loop

# %%
import time

for airport in airport_staids:
    print(airport)
    
    for onemonth in monthly_ranges:
    
        querystring = {
            "station":airport_staids[airport]
            ,"start":onemonth[0]
            ,"end":onemonth[1]
            ,"model":"true"
        }
        
        print(querystring)
        
        time.sleep(0.34)
    print()
# Out:
# MIA
# {'station': 72202, 'start': '2017-09-01', 'end': '2017-09-30', 'model': 'true'}
#
# MCO
# {'station': 72205, 'start': '2017-09-01', 'end': '2017-09-30', 'model': 'true'}
#
# TPA
# {'station': 72211, 'start': '2017-09-01', 'end': '2017-09-30', 'model': 'true'}

# %% [markdown]
# How many API calls would that cost per attempt?

# %% [markdown]
# >#### If the querystrings look reasonable, we can now run the Hourly Data API calls. Fingers crossed!

# %% [markdown]
# ### API CALL hourly ( per station)

# %%
#  let's catch each response in a dictionary. create an empty dictionary with the following keys:
weather_hourly_dict = {'extracted_at':[], 
                       'airport_code':[], 
                       'station_id':[], 
                       'extracted_data':[]}

# API CALL hourly (station) - for the syntax: see the rapidapi interface

url = "https://meteostat.p.rapidapi.com/stations/hourly"

headers = {
        "X-RapidAPI-Key": api_key,
        "X-RapidAPI-Host": "meteostat.p.rapidapi.com"
}


# double for-loop for the querystrings
for airport in airport_staids:
    
    # adding some logs
    print(airport) 
    
    for onemonth in monthly_ranges:
    
        querystring = {
            "station":airport_staids[airport]
            ,"start":onemonth[0]
            ,"end":onemonth[1]
            ,"model":"true"
        }
        
        # making one call with the current querystring
        response = requests.get(url, headers=headers, params=querystring)
        
        # adding some logs to catch errors
        if response.status_code != 200:
            print(f'status code {response.status_code} -> research error')
            print(querystring, end="\n\n")
        else:
            print(querystring)
        
        # appending data to the dictionary:
        weather_hourly_dict['extracted_at'].append(datetime.now())                # timestamp,
        weather_hourly_dict['airport_code'].append(airport)                       # airport code
        weather_hourly_dict['station_id'].append(airport_staids[airport])         # weater Station ID
        weather_hourly_dict['extracted_data'].append(json.loads(response.text))   # JSON string
        
        time.sleep(0.34)
        
    print()
# Out:
# MIA
# {'station': 72202, 'start': '2017-09-01', 'end': '2017-09-30', 'model': 'true'}
#
# MCO
# {'station': 72205, 'start': '2017-09-01', 'end': '2017-09-30', 'model': 'true'}
#
# TPA
# {'station': 72211, 'start': '2017-09-01', 'end': '2017-09-30', 'model': 'true'}

# %%
# checking the dictionary
weather_hourly_dict
# Out:
# {'extracted_at': [datetime.datetime(2025, 2, 13, 20, 1, 47, 613777),
#   datetime.datetime(2025, 2, 13, 20, 1, 48, 250881),
#   datetime.datetime(2025, 2, 13, 20, 1, 48, 951475)],
#  'airport_code': ['MIA', 'MCO', 'TPA'],
#  'station_id': [72202, 72205, 72211],
#  'extracted_data': [{'meta': {'generated': '2025-02-12 20:27:23'},
#    'data': [{'time': '2017-09-01 00:00:00',
#      'temp': 30.6,
#      'dwpt': 23.3,
#      'rhum': 65.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 120.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1015.5,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-01 01:00:00',
#      'temp': 30.0,
#      'dwpt': 24.4,
#      'rhum': 72.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 140.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1016.6,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-01 02:00:00',
#      'temp': 30.0,
#      'dwpt': 23.9,
#      'rhum': 70.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 120.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1017.1,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-01 03:00:00',
#      'temp': 29.4,
#      'dwpt': 23.8,
#      'rhum': 72.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 120.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1017.4,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-01 04:00:00',
#      'temp': 29.4,
#      'dwpt': 23.8,
#      'rhum': 72.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 110.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1017.0,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-01 05:00:00',
#      'temp': 29.4,
#      'dwpt': 23.8,
#      'rhum': 72.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 100.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1016.8,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-01 06:00:00',
#      'temp': 29.4,
#      'dwpt': 23.8,
#      'rhum': 72.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 100.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1016.7,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-01 07:00:00',
#      'temp': 29.4,
#      'dwpt': 23.8,
#      'rhum': 72.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 80.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1015.5,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-01 08:00:00',
#      'temp': 29.4,
#      'dwpt': 24.5,
#      'rhum': 75.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 80.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1015.4,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-01 09:00:00',
#      'temp': 29.4,
#      'dwpt': 24.5,
#      'rhum': 75.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 110.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1016.0,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-01 10:00:00',
#      'temp': 30.0,
#      'dwpt': 25.1,
#      'rhum': 75.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 100.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1016.1,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-01 11:00:00',
#      'temp': 29.4,
#      'dwpt': 24.9,
#      'rhum': 77.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 120.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1017.2,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-01 12:00:00',
#      'temp': 30.0,
#      'dwpt': 25.1,
#      'rhum': 75.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 110.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1017.1,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-01 13:00:00',
#      'temp': 30.6,
#      'dwpt': 24.5,
#      'rhum': 70.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 100.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1017.1,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-01 14:00:00',
#      'temp': 31.7,
#      'dwpt': 24.3,
#      'rhum': 65.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 100.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1017.5,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-01 15:00:00',
#      'temp': 32.2,
#      'dwpt': 25.0,
#      'rhum': 66.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 120.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1018.0,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-01 16:00:00',
#      'temp': 32.8,
#      'dwpt': 24.3,
#      'rhum': 61.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 150.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1017.8,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-01 17:00:00',
#      'temp': 33.3,
#      'dwpt': 25.6,
#      'rhum': 64.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 150.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1017.3,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-01 18:00:00',
#      'temp': 33.9,
#      'dwpt': 25.0,
#      'rhum': 60.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 120.0,
#      'wspd': 20.5,
#      'wpgt': None,
#      'pres': 1016.7,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-01 19:00:00',
#      'temp': 33.9,
#      'dwpt': 25.0,
#      'rhum': 60.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 120.0,
#      'wspd': 24.1,
#      'wpgt': None,
#      'pres': 1016.1,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-01 20:00:00',
#      'temp': 33.3,
#      'dwpt': 25.0,
#      'rhum': 62.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 130.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1015.6,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-01 21:00:00',
#      'temp': 32.8,
#      'dwpt': 24.0,
#      'rhum': 60.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 130.0,
#      'wspd': 22.3,
#      'wpgt': None,
#      'pres': 1014.7,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-01 22:00:00',
#      'temp': 31.1,
#      'dwpt': 24.0,
#      'rhum': 66.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 130.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1014.9,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-01 23:00:00',
#      'temp': 31.1,
#      'dwpt': 25.0,
#      'rhum': 70.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 150.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1015.3,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-02 00:00:00',
#      'temp': 30.6,
#      'dwpt': 25.0,
#      'rhum': 72.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 170.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1016.0,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-02 01:00:00',
#      'temp': 30.6,
#      'dwpt': 25.0,
#      'rhum': 72.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 160.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1016.7,
#      'tsun': None,
#      'coco': 25},
#     {'time': '2017-09-02 02:00:00',
#      'temp': 26.7,
#      'dwpt': 22.8,
#      'rhum': 79.0,
#      'prcp': 11.2,
#      'snow': None,
#      'wdir': 70.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1017.7,
#      'tsun': None,
#      'coco': 25},
#     {'time': '2017-09-02 03:00:00',
#      'temp': 27.2,
#      'dwpt': 23.2,
#      'rhum': 79.0,
#      'prcp': 0.3,
#      'snow': None,
#      'wdir': None,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1017.8,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-02 04:00:00',
#      'temp': 28.3,
#      'dwpt': 24.9,
#      'rhum': 82.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1017.6,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-02 05:00:00',
#      'temp': 27.8,
#      'dwpt': 25.6,
#      'rhum': 88.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 320.0,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1017.2,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-02 06:00:00',
#      'temp': 27.2,
#      'dwpt': 23.2,
#      'rhum': 79.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 320.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1017.4,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-02 07:00:00',
#      'temp': 27.2,
#      'dwpt': 22.8,
#      'rhum': 77.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 40.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1017.0,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-02 08:00:00',
#      'temp': 26.7,
#      'dwpt': 22.8,
#      'rhum': 79.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 40.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1016.2,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-02 09:00:00',
#      'temp': 26.7,
#      'dwpt': 22.8,
#      'rhum': 79.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 30.0,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1016.7,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-02 10:00:00',
#      'temp': 26.7,
#      'dwpt': 22.8,
#      'rhum': 79.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 30.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1016.8,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-02 11:00:00',
#      'temp': 26.7,
#      'dwpt': 22.8,
#      'rhum': 79.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 350.0,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1017.8,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-02 12:00:00',
#      'temp': 27.2,
#      'dwpt': 23.2,
#      'rhum': 79.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 350.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1018.1,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-02 13:00:00',
#      'temp': 28.3,
#      'dwpt': 23.9,
#      'rhum': 77.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 250.0,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1018.8,
#      'tsun': None,
#      'coco': 26},
#     {'time': '2017-09-02 14:00:00',
#      'temp': 23.9,
#      'dwpt': 21.0,
#      'rhum': 84.0,
#      'prcp': 20.8,
#      'snow': None,
#      'wdir': 100.0,
#      'wspd': 33.5,
#      'wpgt': None,
#      'pres': 1020.7,
#      'tsun': None,
#      'coco': 7},
#     {'time': '2017-09-02 15:00:00',
#      'temp': 23.9,
#      'dwpt': 21.8,
#      'rhum': 88.0,
#      'prcp': 5.3,
#      'snow': None,
#      'wdir': None,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1018.5,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-02 16:00:00',
#      'temp': 26.1,
#      'dwpt': 23.8,
#      'rhum': 87.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': None,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1018.1,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-02 17:00:00',
#      'temp': 26.7,
#      'dwpt': 24.0,
#      'rhum': 85.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 160.0,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1017.8,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-02 18:00:00',
#      'temp': 28.9,
#      'dwpt': 26.7,
#      'rhum': 88.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 160.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1017.3,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-02 19:00:00',
#      'temp': 31.1,
#      'dwpt': 26.8,
#      'rhum': 78.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 150.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1017.0,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-02 20:00:00',
#      'temp': 31.1,
#      'dwpt': 26.0,
#      'rhum': 75.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 170.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1016.7,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-02 21:00:00',
#      'temp': 31.1,
#      'dwpt': 25.7,
#      'rhum': 73.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 180.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1016.8,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-02 22:00:00',
#      'temp': 30.6,
#      'dwpt': 26.1,
#      'rhum': 77.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 150.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1016.9,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-02 23:00:00',
#      'temp': 29.4,
#      'dwpt': 26.0,
#      'rhum': 82.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 150.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1017.1,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-03 00:00:00',
#      'temp': 29.4,
#      'dwpt': 26.0,
#      'rhum': 82.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 160.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1017.4,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-03 01:00:00',
#      'temp': 28.9,
#      'dwpt': 25.5,
#      'rhum': 82.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 160.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1017.7,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-03 02:00:00',
#      'temp': 28.3,
#      'dwpt': 26.1,
#      'rhum': 88.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 190.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1018.5,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-03 03:00:00',
#      'temp': 28.3,
#      'dwpt': 26.1,
#      'rhum': 88.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 160.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1018.6,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-03 04:00:00',
#      'temp': 28.3,
#      'dwpt': 26.1,
#      'rhum': 88.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1018.3,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-03 05:00:00',
#      'temp': 28.3,
#      'dwpt': 26.1,
#      'rhum': 88.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 160.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1018.1,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-03 06:00:00',
#      'temp': 27.8,
#      'dwpt': 26.0,
#      'rhum': 90.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1017.8,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-03 07:00:00',
#      'temp': 27.2,
#      'dwpt': 25.6,
#      'rhum': 91.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1017.5,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-03 08:00:00',
#      'temp': 26.7,
#      'dwpt': 25.7,
#      'rhum': 94.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1017.1,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-03 09:00:00',
#      'temp': 27.2,
#      'dwpt': 25.6,
#      'rhum': 91.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1017.1,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-03 10:00:00',
#      'temp': 26.7,
#      'dwpt': 25.7,
#      'rhum': 94.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1017.5,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-03 11:00:00',
#      'temp': 26.7,
#      'dwpt': 25.7,
#      'rhum': 94.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1018.0,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-03 12:00:00',
#      'temp': 26.7,
#      'dwpt': 25.7,
#      'rhum': 94.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1018.6,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-03 13:00:00',
#      'temp': 28.9,
#      'dwpt': 27.8,
#      'rhum': 94.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1018.8,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-03 14:00:00',
#      'temp': 31.1,
#      'dwpt': 27.2,
#      'rhum': 80.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 20.0,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1019.1,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-03 15:00:00',
#      'temp': 31.7,
#      'dwpt': 26.7,
#      'rhum': 75.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 20.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1019.3,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-03 16:00:00',
#      'temp': 32.8,
#      'dwpt': 26.6,
#      'rhum': 70.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 80.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1018.9,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-03 17:00:00',
#      'temp': 33.3,
#      'dwpt': 27.1,
#      'rhum': 70.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 120.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1018.6,
#      'tsun': None,
#      'coco': 25},
#     {'time': '2017-09-03 18:00:00',
#      'temp': 33.9,
#      'dwpt': 27.9,
#      'rhum': 71.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 140.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1018.1,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-03 19:00:00',
#      'temp': 33.3,
#      'dwpt': 26.6,
#      'rhum': 68.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 130.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1017.4,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-03 20:00:00',
#      'temp': 30.6,
#      'dwpt': 24.5,
#      'rhum': 70.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 90.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1016.8,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-03 21:00:00',
#      'temp': 31.7,
#      'dwpt': 22.1,
#      'rhum': 57.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 110.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1016.5,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-03 22:00:00',
#      'temp': 31.1,
#      'dwpt': 24.5,
#      'rhum': 68.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 100.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1016.4,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-03 23:00:00',
#      'temp': 28.9,
#      'dwpt': 26.1,
#      'rhum': 85.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 90.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1017.4,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-04 00:00:00',
#      'temp': 28.9,
#      'dwpt': 23.3,
#      'rhum': 72.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 100.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1017.4,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-04 01:00:00',
#      'temp': 28.3,
#      'dwpt': 24.9,
#      'rhum': 82.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 20.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1017.8,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-04 02:00:00',
#      'temp': 28.3,
#      'dwpt': 24.9,
#      'rhum': 82.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 350.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1018.3,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-04 03:00:00',
#      'temp': 27.8,
#      'dwpt': 25.0,
#      'rhum': 85.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 340.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1018.5,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-04 04:00:00',
#      'temp': 27.8,
#      'dwpt': 25.0,
#      'rhum': 85.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 360.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1018.1,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-04 05:00:00',
#      'temp': 26.7,
#      'dwpt': 24.4,
#      'rhum': 87.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 10.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1017.8,
#      'tsun': None,
#      'coco': 7},
#     {'time': '2017-09-04 06:00:00',
#      'temp': 27.2,
#      'dwpt': 24.5,
#      'rhum': 85.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 50.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1017.5,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-04 07:00:00',
#      'temp': 27.2,
#      'dwpt': 24.5,
#      'rhum': 85.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 40.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1016.9,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-04 08:00:00',
#      'temp': 26.7,
#      'dwpt': 24.4,
#      'rhum': 87.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 30.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1016.6,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-04 09:00:00',
#      'temp': 26.7,
#      'dwpt': 24.0,
#      'rhum': 85.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 50.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1016.3,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-04 10:00:00',
#      'temp': 26.1,
#      'dwpt': 24.0,
#      'rhum': 88.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 40.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1016.3,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-04 11:00:00',
#      'temp': 26.1,
#      'dwpt': 24.0,
#      'rhum': 88.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 40.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1016.8,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-04 12:00:00',
#      'temp': 28.3,
#      'dwpt': 24.3,
#      'rhum': 79.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 30.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1017.0,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-04 13:00:00',
#      'temp': 28.9,
#      'dwpt': 25.1,
#      'rhum': 80.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 30.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1017.3,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-04 14:00:00',
#      'temp': 31.1,
#      'dwpt': 24.5,
#      'rhum': 68.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 90.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1017.8,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-04 15:00:00',
#      'temp': 31.1,
#      'dwpt': 25.0,
#      'rhum': 70.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 70.0,
#      'wspd': 22.3,
#      'wpgt': None,
#      'pres': 1018.0,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-04 16:00:00',
#      'temp': 32.8,
#      'dwpt': 24.3,
#      'rhum': 61.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 90.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': None,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-04 17:00:00',
#      'temp': 33.3,
#      'dwpt': 25.0,
#      'rhum': 62.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 90.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1017.3,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-04 18:00:00',
#      'temp': 32.8,
#      'dwpt': 24.3,
#      'rhum': 61.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 100.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1016.8,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-04 19:00:00',
#      'temp': 33.3,
#      'dwpt': 25.6,
#      'rhum': 64.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 80.0,
#      'wspd': 24.1,
#      'wpgt': None,
#      'pres': 1016.3,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-04 20:00:00',
#      'temp': 31.7,
#      'dwpt': 25.6,
#      'rhum': 70.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 80.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1015.5,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-04 21:00:00',
#      'temp': 30.6,
#      'dwpt': 26.1,
#      'rhum': 77.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 100.0,
#      'wspd': 20.5,
#      'wpgt': None,
#      'pres': 1014.9,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-04 22:00:00',
#      'temp': 30.6,
#      'dwpt': 25.7,
#      'rhum': 75.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 100.0,
#      'wspd': 24.1,
#      'wpgt': None,
#      'pres': 1015.0,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-04 23:00:00',
#      'temp': 29.4,
#      'dwpt': 24.9,
#      'rhum': 77.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 90.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1015.5,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-05 00:00:00',
#      'temp': 29.4,
#      'dwpt': 26.0,
#      'rhum': 82.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 80.0,
#      'wspd': 24.1,
#      'wpgt': None,
#      'pres': 1016.0,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-05 01:00:00',
#      'temp': 28.9,
#      'dwpt': 26.7,
#      'rhum': 88.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 70.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1016.2,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-05 02:00:00',
#      'temp': 28.9,
#      'dwpt': 26.7,
#      'rhum': 88.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 90.0,
#      'wspd': 22.3,
#      'wpgt': None,
#      'pres': 1016.7,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-05 03:00:00',
#      'temp': 28.9,
#      'dwpt': 26.1,
#      'rhum': 85.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 80.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1016.7,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-05 04:00:00',
#      'temp': 28.9,
#      'dwpt': 26.1,
#      'rhum': 85.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 100.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1016.4,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-05 05:00:00',
#      'temp': 28.9,
#      'dwpt': 25.5,
#      'rhum': 82.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 100.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1015.7,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-05 06:00:00',
#      'temp': 26.7,
#      'dwpt': 24.9,
#      'rhum': 90.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 120.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1015.6,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-05 07:00:00',
#      'temp': 26.1,
#      'dwpt': 25.1,
#      'rhum': 94.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 110.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1014.9,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-05 08:00:00',
#      'temp': 27.8,
#      'dwpt': 25.0,
#      'rhum': 85.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 110.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1014.7,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-05 09:00:00',
#      'temp': 27.8,
#      'dwpt': 25.0,
#      'rhum': 85.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 110.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1014.7,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-05 10:00:00',
#      'temp': 27.8,
#      'dwpt': 24.4,
#      'rhum': 82.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 10.0,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1014.8,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-05 11:00:00',
#      'temp': 27.8,
#      'dwpt': 24.4,
#      'rhum': 82.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 10.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1015.2,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-05 12:00:00',
#      'temp': 28.3,
#      'dwpt': 24.3,
#      'rhum': 79.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 60.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1015.6,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-05 13:00:00',
#      'temp': 30.0,
#      'dwpt': 25.1,
#      'rhum': 75.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 90.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1016.1,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-05 14:00:00',
#      'temp': 31.7,
#      'dwpt': 25.1,
#      'rhum': 68.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 90.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1016.4,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-05 15:00:00',
#      'temp': 32.8,
#      'dwpt': 24.0,
#      'rhum': 60.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 130.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1016.5,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-05 16:00:00',
#      'temp': 32.8,
#      'dwpt': 24.3,
#      'rhum': 61.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 120.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1016.2,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-05 17:00:00',
#      'temp': 33.8,
#      'dwpt': 23.2,
#      'rhum': 54.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 140.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1015.5,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-05 18:00:00',
#      'temp': 33.7,
#      'dwpt': 25.1,
#      'rhum': 61.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 130.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1014.7,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-05 19:00:00',
#      'temp': 33.9,
#      'dwpt': 25.0,
#      'rhum': 60.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 120.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1013.7,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-05 20:00:00',
#      'temp': 32.8,
#      'dwpt': 25.1,
#      'rhum': 64.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 90.0,
#      'wspd': 20.5,
#      'wpgt': None,
#      'pres': 1013.6,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-05 21:00:00',
#      'temp': 31.1,
#      'dwpt': 24.5,
#      'rhum': 68.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 90.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1013.2,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-05 22:00:00',
#      'temp': 30.6,
#      'dwpt': 23.3,
#      'rhum': 65.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 90.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1012.8,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-05 23:00:00',
#      'temp': 30.0,
#      'dwpt': 24.4,
#      'rhum': 72.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 100.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1012.8,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-06 00:00:00',
#      'temp': 30.0,
#      'dwpt': 24.4,
#      'rhum': 72.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 100.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1013.5,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-06 01:00:00',
#      'temp': 29.4,
#      'dwpt': 26.0,
#      'rhum': 82.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 100.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1014.2,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-06 02:00:00',
#      'temp': 28.9,
#      'dwpt': 24.5,
#      'rhum': 77.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 120.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1014.5,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-06 03:00:00',
#      'temp': 28.9,
#      'dwpt': 25.5,
#      'rhum': 82.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 120.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1014.7,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-06 04:00:00',
#      'temp': 28.9,
#      'dwpt': 25.1,
#      'rhum': 80.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 110.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1014.6,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-06 05:00:00',
#      'temp': 28.9,
#      'dwpt': 25.1,
#      'rhum': 80.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 110.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1014.4,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-06 06:00:00',
#      'temp': 28.9,
#      'dwpt': 25.1,
#      'rhum': 80.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 130.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1014.1,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-06 07:00:00',
#      'temp': 28.0,
#      'dwpt': 26.2,
#      'rhum': 90.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 120.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1013.3,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-06 08:00:00',
#      'temp': 28.3,
#      'dwpt': 26.1,
#      'rhum': 88.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 100.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1012.7,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-06 09:00:00',
#      'temp': 27.8,
#      'dwpt': 25.6,
#      'rhum': 88.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 140.0,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1012.7,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-06 10:00:00',
#      'temp': 27.8,
#      'dwpt': 26.0,
#      'rhum': 90.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 140.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1012.7,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-06 11:00:00',
#      'temp': 27.8,
#      'dwpt': 26.0,
#      'rhum': 90.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 110.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1013.2,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-06 12:00:00',
#      'temp': 29.0,
#      'dwpt': 25.0,
#      'rhum': 79.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 120.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1013.3,
#      'tsun': None,
#      'coco': 7},
#     {'time': '2017-09-06 13:00:00',
#      'temp': 29.4,
#      'dwpt': 24.9,
#      'rhum': 77.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 200.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1013.8,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-06 14:00:00',
#      'temp': 30.6,
#      'dwpt': 25.7,
#      'rhum': 75.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 140.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1014.0,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-06 15:00:00',
#      'temp': 31.7,
#      'dwpt': 25.6,
#      'rhum': 70.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 190.0,
#      'wspd': 25.9,
#      'wpgt': None,
#      'pres': 1014.2,
#      'tsun': None,
#      'coco': 7},
#     {'time': '2017-09-06 16:00:00',
#      'temp': 29.4,
#      'dwpt': 23.8,
#      'rhum': 72.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 120.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1014.1,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-06 17:00:00',
#      'temp': 32.2,
#      'dwpt': 24.5,
#      'rhum': 64.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 120.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1013.5,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-06 18:00:00',
#      'temp': 32.8,
#      'dwpt': 24.3,
#      'rhum': 61.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 130.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1013.2,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-06 19:00:00',
#      'temp': 31.7,
#      'dwpt': 23.8,
#      'rhum': 63.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 140.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1012.7,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-06 20:00:00',
#      'temp': 30.6,
#      'dwpt': 24.5,
#      'rhum': 70.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 130.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1012.4,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-06 21:00:00',
#      'temp': 30.6,
#      'dwpt': 24.0,
#      'rhum': 68.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 140.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1012.2,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-06 22:00:00',
#      'temp': 30.0,
#      'dwpt': 24.4,
#      'rhum': 72.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1012.6,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-06 23:00:00',
#      'temp': 29.4,
#      'dwpt': 23.4,
#      'rhum': 70.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1013.0,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-07 00:00:00',
#      'temp': 30.0,
#      'dwpt': 23.2,
#      'rhum': 67.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1013.5,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-07 01:00:00',
#      'temp': 29.4,
#      'dwpt': 23.8,
#      'rhum': 72.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 130.0,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1013.7,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-07 02:00:00',
#      'temp': 28.9,
#      'dwpt': 24.5,
#      'rhum': 77.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 130.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1014.6,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-07 03:00:00',
#      'temp': 28.9,
#      'dwpt': 24.5,
#      'rhum': 77.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': None,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1015.1,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-07 04:00:00',
#      'temp': 29.4,
#      'dwpt': 24.9,
#      'rhum': 77.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 120.0,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1015.2,
#      'tsun': None,
#      'coco': 7},
#     {'time': '2017-09-07 05:00:00',
#      'temp': 28.9,
#      'dwpt': 24.5,
#      'rhum': 77.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 120.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1014.8,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-07 06:00:00',
#      'temp': 27.8,
#      'dwpt': 24.4,
#      'rhum': 82.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 100.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1014.8,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-07 07:00:00',
#      'temp': 28.3,
#      'dwpt': 23.9,
#      'rhum': 77.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': None,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1014.0,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-07 08:00:00',
#      'temp': 27.8,
#      'dwpt': 23.8,
#      'rhum': 79.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 110.0,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1013.6,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-07 09:00:00',
#      'temp': 28.3,
#      'dwpt': 24.3,
#      'rhum': 79.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 110.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1013.4,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-07 10:00:00',
#      'temp': 28.3,
#      'dwpt': 24.3,
#      'rhum': 79.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 100.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1013.4,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-07 11:00:00',
#      'temp': 27.8,
#      'dwpt': 24.4,
#      'rhum': 82.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 110.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1013.3,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-07 12:00:00',
#      'temp': 28.9,
#      'dwpt': 25.5,
#      'rhum': 82.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 90.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1013.8,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-07 13:00:00',
#      'temp': 30.6,
#      'dwpt': 25.0,
#      'rhum': 72.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 130.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1014.2,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-07 14:00:00',
#      'temp': 30.6,
#      'dwpt': 24.5,
#      'rhum': 70.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 140.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1014.7,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-07 15:00:00',
#      'temp': 32.2,
#      'dwpt': 25.0,
#      'rhum': 66.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 140.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1014.8,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-07 16:00:00',
#      'temp': 32.8,
#      'dwpt': 24.0,
#      'rhum': 60.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 140.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1014.8,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-07 17:00:00',
#      'temp': 33.3,
#      'dwpt': 24.5,
#      'rhum': 60.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 120.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1014.4,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-07 18:00:00',
#      'temp': 33.3,
#      'dwpt': 23.9,
#      'rhum': 58.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 90.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1013.9,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-07 19:00:00',
#      'temp': 33.9,
#      'dwpt': 23.9,
#      'rhum': 56.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 90.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1013.4,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-07 20:00:00',
#      'temp': 33.9,
#      'dwpt': 24.5,
#      'rhum': 58.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 100.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1013.0,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-07 21:00:00',
#      'temp': 32.8,
#      'dwpt': 24.0,
#      'rhum': 60.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 120.0,
#      'wspd': 22.3,
#      'wpgt': None,
#      'pres': 1012.8,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-07 22:00:00',
#      'temp': 31.7,
#      'dwpt': 23.8,
#      'rhum': 63.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 110.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1012.9,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-07 23:00:00',
#      'temp': 31.1,
#      'dwpt': 24.5,
#      'rhum': 68.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 60.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1013.5,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-08 00:00:00',
#      'temp': 31.1,
#      'dwpt': 24.0,
#      'rhum': 66.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 100.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1013.4,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-08 01:00:00',
#      'temp': 30.6,
#      'dwpt': 24.5,
#      'rhum': 70.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 100.0,
#      'wspd': 20.5,
#      'wpgt': None,
#      'pres': 1014.0,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-08 02:00:00',
#      'temp': 30.6,
#      'dwpt': 25.0,
#      'rhum': 72.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 70.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1014.6,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-08 03:00:00',
#      'temp': 30.6,
#      'dwpt': 25.0,
#      'rhum': 72.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 40.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1015.0,
#      'tsun': None,
#      'coco': 25},
#     {'time': '2017-09-08 04:00:00',
#      'temp': 30.0,
#      'dwpt': 25.1,
#      'rhum': 75.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 80.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1014.5,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-08 05:00:00',
#      'temp': 30.0,
#      'dwpt': 25.1,
#      'rhum': 75.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1014.6,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-08 06:00:00',
#      'temp': 30.0,
#      'dwpt': 25.1,
#      'rhum': 75.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 40.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1013.7,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-08 07:00:00',
#      'temp': 29.4,
#      'dwpt': 24.9,
#      'rhum': 77.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 40.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1012.9,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-08 08:00:00',
#      'temp': 29.4,
#      'dwpt': 25.6,
#      'rhum': 80.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 80.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1012.0,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-08 09:00:00',
#      'temp': 29.4,
#      'dwpt': 25.6,
#      'rhum': 80.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 50.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1012.0,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-08 10:00:00',
#      'temp': 29.4,
#      'dwpt': 25.6,
#      'rhum': 80.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 40.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1011.9,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-08 11:00:00',
#      'temp': 29.4,
#      'dwpt': 24.9,
#      'rhum': 77.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 40.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1011.9,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-08 12:00:00',
#      'temp': 29.4,
#      'dwpt': 24.9,
#      'rhum': 77.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 20.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1012.2,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-08 13:00:00',
#      'temp': 31.1,
#      'dwpt': 25.0,
#      'rhum': 70.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 40.0,
#      'wspd': 20.5,
#      'wpgt': None,
#      'pres': 1012.7,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-08 14:00:00',
#      'temp': 31.7,
#      'dwpt': 24.3,
#      'rhum': 65.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 50.0,
#      'wspd': 20.5,
#      'wpgt': None,
#      'pres': 1013.1,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-08 15:00:00',
#      'temp': 31.7,
#      'dwpt': 24.3,
#      'rhum': 65.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 50.0,
#      'wspd': 20.5,
#      'wpgt': None,
#      'pres': 1013.5,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-08 16:00:00',
#      'temp': 33.9,
#      'dwpt': 23.9,
#      'rhum': 56.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 50.0,
#      'wspd': 25.9,
#      'wpgt': None,
#      'pres': 1013.6,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-08 17:00:00',
#      'temp': 33.3,
#      'dwpt': 24.5,
#      'rhum': 60.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 40.0,
#      'wspd': 27.7,
#      'wpgt': None,
#      'pres': 1012.6,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-08 18:00:00',
#      'temp': 33.9,
#      'dwpt': 24.5,
#      'rhum': 58.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 70.0,
#      'wspd': 24.1,
#      'wpgt': None,
#      'pres': 1011.4,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-08 19:00:00',
#      'temp': 34.4,
#      'dwpt': 23.8,
#      'rhum': 54.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 50.0,
#      'wspd': 20.5,
#      'wpgt': None,
#      'pres': 1010.2,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-08 20:00:00',
#      'temp': 33.3,
#      'dwpt': 24.5,
#      'rhum': 60.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 50.0,
#      'wspd': 22.3,
#      'wpgt': None,
#      'pres': 1009.4,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-08 21:00:00',
#      'temp': 32.8,
#      'dwpt': 24.3,
#      'rhum': 61.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 30.0,
#      'wspd': 24.1,
#      'wpgt': None,
#      'pres': 1009.4,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-08 22:00:00',
#      'temp': 32.2,
#      'dwpt': 23.2,
#      'rhum': 59.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 50.0,
#      'wspd': 24.1,
#      'wpgt': None,
#      'pres': 1009.5,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-08 23:00:00',
#      'temp': 31.7,
#      'dwpt': 24.3,
#      'rhum': 65.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 30.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1009.2,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-09 00:00:00',
#      'temp': 31.1,
#      'dwpt': 24.5,
#      'rhum': 68.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 40.0,
#      'wspd': 22.3,
#      'wpgt': None,
#      'pres': 1009.3,
# ...
#      'dwpt': 22.1,
#      'rhum': 76.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 30.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1012.2,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-28 08:00:00',
#      'temp': 26.1,
#      'dwpt': 22.2,
#      'rhum': 79.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1012.0,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-28 09:00:00',
#      'temp': 26.1,
#      'dwpt': 22.2,
#      'rhum': 79.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1011.8,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-28 10:00:00',
#      'temp': 25.6,
#      'dwpt': 22.9,
#      'rhum': 85.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1012.0,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-28 11:00:00',
#      'temp': 25.6,
#      'dwpt': 22.9,
#      'rhum': 85.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1012.5,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-28 12:00:00',
#      'temp': 25.6,
#      'dwpt': 22.9,
#      'rhum': 85.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 90.0,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1012.9,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-28 13:00:00',
#      'temp': 27.2,
#      'dwpt': 22.8,
#      'rhum': 77.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 90.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1013.5,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-28 14:00:00',
#      'temp': 29.4,
#      'dwpt': 22.9,
#      'rhum': 68.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 160.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1013.6,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-28 15:00:00',
#      'temp': 31.1,
#      'dwpt': 21.6,
#      'rhum': 57.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 60.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1013.6,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-28 16:00:00',
#      'temp': 32.8,
#      'dwpt': 20.0,
#      'rhum': 47.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1013.5,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-28 17:00:00',
#      'temp': 31.1,
#      'dwpt': 23.2,
#      'rhum': 63.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1012.7,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-28 18:00:00',
#      'temp': 31.7,
#      'dwpt': 23.3,
#      'rhum': 61.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 260.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1012.0,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-28 19:00:00',
#      'temp': 33.9,
#      'dwpt': 22.3,
#      'rhum': 51.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 250.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1011.4,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-28 20:00:00',
#      'temp': 33.3,
#      'dwpt': 21.8,
#      'rhum': 51.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1010.9,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-28 21:00:00',
#      'temp': 33.3,
#      'dwpt': 22.1,
#      'rhum': 52.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 290.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1010.6,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-28 22:00:00',
#      'temp': 32.2,
#      'dwpt': 22.3,
#      'rhum': 56.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 310.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1010.6,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-28 23:00:00',
#      'temp': 31.7,
#      'dwpt': 22.1,
#      'rhum': 57.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 330.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1011.1,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-29 00:00:00',
#      'temp': 31.1,
#      'dwpt': 21.6,
#      'rhum': 57.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 330.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1011.8,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-29 01:00:00',
#      'temp': 29.4,
#      'dwpt': 21.6,
#      'rhum': 63.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 350.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1012.6,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-29 02:00:00',
#      'temp': 30.0,
#      'dwpt': 21.7,
#      'rhum': 61.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 60.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1013.4,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-29 03:00:00',
#      'temp': 29.4,
#      'dwpt': 22.9,
#      'rhum': 68.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 120.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1013.5,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-29 04:00:00',
#      'temp': 28.3,
#      'dwpt': 23.2,
#      'rhum': 74.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 130.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1013.2,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-29 05:00:00',
#      'temp': 27.8,
#      'dwpt': 23.4,
#      'rhum': 77.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 110.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1013.4,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-29 06:00:00',
#      'temp': 27.2,
#      'dwpt': 23.9,
#      'rhum': 82.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 120.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1013.3,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-29 07:00:00',
#      'temp': 27.2,
#      'dwpt': 23.9,
#      'rhum': 82.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 120.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1012.9,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-29 08:00:00',
#      'temp': 26.7,
#      'dwpt': 23.4,
#      'rhum': 82.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 50.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1012.6,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-29 09:00:00',
#      'temp': 26.7,
#      'dwpt': 23.4,
#      'rhum': 82.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 70.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1012.7,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-29 10:00:00',
#      'temp': 26.1,
#      'dwpt': 23.4,
#      'rhum': 85.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 90.0,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1012.8,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-29 11:00:00',
#      'temp': 26.1,
#      'dwpt': 22.8,
#      'rhum': 82.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 90.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1013.1,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-29 12:00:00',
#      'temp': 25.6,
#      'dwpt': 22.9,
#      'rhum': 85.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 70.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1013.7,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-29 13:00:00',
#      'temp': 26.1,
#      'dwpt': 23.4,
#      'rhum': 85.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 60.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1014.1,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-29 14:00:00',
#      'temp': 27.8,
#      'dwpt': 23.8,
#      'rhum': 79.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 60.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1014.3,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-29 15:00:00',
#      'temp': 30.0,
#      'dwpt': 22.7,
#      'rhum': 65.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 30.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1014.2,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-29 16:00:00',
#      'temp': 31.7,
#      'dwpt': 21.6,
#      'rhum': 55.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 270.0,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1014.3,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-29 17:00:00',
#      'temp': 31.1,
#      'dwpt': 22.7,
#      'rhum': 61.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 270.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1013.6,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-29 18:00:00',
#      'temp': 30.6,
#      'dwpt': 23.3,
#      'rhum': 65.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 270.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1012.8,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-29 19:00:00',
#      'temp': 31.1,
#      'dwpt': 22.1,
#      'rhum': 59.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1012.2,
#      'tsun': None,
#      'coco': 7},
#     {'time': '2017-09-29 20:00:00',
#      'temp': 32.2,
#      'dwpt': 22.3,
#      'rhum': 56.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1011.7,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-29 21:00:00',
#      'temp': 31.7,
#      'dwpt': 22.7,
#      'rhum': 59.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 230.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1011.4,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-29 22:00:00',
#      'temp': 28.3,
#      'dwpt': 22.8,
#      'rhum': 72.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 100.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1012.1,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-29 23:00:00',
#      'temp': 27.8,
#      'dwpt': 22.7,
#      'rhum': 74.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 70.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1013.5,
#      'tsun': None,
#      'coco': 7},
#     {'time': '2017-09-30 00:00:00',
#      'temp': 26.7,
#      'dwpt': 23.4,
#      'rhum': 82.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 80.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1014.1,
#      'tsun': None,
#      'coco': 7},
#     {'time': '2017-09-30 01:00:00',
#      'temp': 25.6,
#      'dwpt': 22.3,
#      'rhum': 82.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': None,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1014.3,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-30 02:00:00',
#      'temp': 25.6,
#      'dwpt': 21.7,
#      'rhum': 79.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': None,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1014.1,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-30 03:00:00',
#      'temp': 25.6,
#      'dwpt': 22.3,
#      'rhum': 82.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1013.8,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-30 04:00:00',
#      'temp': 26.1,
#      'dwpt': 21.1,
#      'rhum': 74.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1014.1,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-30 05:00:00',
#      'temp': 26.1,
#      'dwpt': 21.8,
#      'rhum': 77.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1013.9,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-30 06:00:00',
#      'temp': 26.1,
#      'dwpt': 22.2,
#      'rhum': 79.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 10.0,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1013.4,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-30 07:00:00',
#      'temp': 25.6,
#      'dwpt': 22.3,
#      'rhum': 82.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 10.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1013.0,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-30 08:00:00',
#      'temp': 25.0,
#      'dwpt': 22.1,
#      'rhum': 84.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 340.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1013.0,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-30 09:00:00',
#      'temp': 25.6,
#      'dwpt': 22.3,
#      'rhum': 82.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1013.2,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-30 10:00:00',
#      'temp': 25.6,
#      'dwpt': 22.3,
#      'rhum': 82.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1013.4,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-30 11:00:00',
#      'temp': 25.0,
#      'dwpt': 22.1,
#      'rhum': 84.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 360.0,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1013.6,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-30 12:00:00',
#      'temp': 25.0,
#      'dwpt': 22.1,
#      'rhum': 84.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 360.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1014.0,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-30 13:00:00',
#      'temp': 26.7,
#      'dwpt': 22.1,
#      'rhum': 76.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 350.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1014.4,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-30 14:00:00',
#      'temp': 26.7,
#      'dwpt': 21.7,
#      'rhum': 74.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 10.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1015.0,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-30 15:00:00',
#      'temp': 28.3,
#      'dwpt': 22.3,
#      'rhum': 70.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1015.0,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-30 16:00:00',
#      'temp': 30.0,
#      'dwpt': 22.2,
#      'rhum': 63.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1014.7,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-30 17:00:00',
#      'temp': 29.4,
#      'dwpt': 23.4,
#      'rhum': 70.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1014.5,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-30 18:00:00',
#      'temp': 30.6,
#      'dwpt': 23.3,
#      'rhum': 65.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 270.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1013.6,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-30 19:00:00',
#      'temp': 30.0,
#      'dwpt': 22.2,
#      'rhum': 63.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 250.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1013.2,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-30 20:00:00',
#      'temp': 28.9,
#      'dwpt': 23.3,
#      'rhum': 72.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1012.7,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-30 21:00:00',
#      'temp': 28.3,
#      'dwpt': 22.3,
#      'rhum': 70.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 340.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1012.9,
#      'tsun': None,
#      'coco': None},
#     {'time': '2017-09-30 22:00:00',
#      'temp': 27.2,
#      'dwpt': 21.7,
#      'rhum': 72.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 340.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1012.9,
#      'tsun': None,
#      'coco': 7},
#     {'time': '2017-09-30 23:00:00',
#      'temp': 26.1,
#      'dwpt': 22.8,
#      'rhum': 82.0,
#      'prcp': 0.8,
#      'snow': None,
#      'wdir': 10.0,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1013.3,
#      'tsun': None,
#      'coco': None}]}]}

# %%
# creating a dataframe

weather_hourly_df = pd.DataFrame(weather_hourly_dict)
weather_hourly_df
# Out:
#                 extracted_at airport_code  station_id  \
# 0 2025-02-13 20:01:47.613777          MIA       72202
# 1 2025-02-13 20:01:48.250881          MCO       72205
# 2 2025-02-13 20:01:48.951475          TPA       72211
#
#                                       extracted_data
# 0  {'meta': {'generated': '2025-02-12 20:27:23'},...
# 1  {'meta': {'generated': '2025-02-12 20:27:24'},...
# 2  {'meta': {'generated': '2025-02-12 20:27:25'},...

# %% [markdown]
# ### SIDEBAR: For the curious and sceptics...

# %% [markdown]
#     In case you can't resist to know what the data looks like when flattened.
#     Here is the preview with pandas. BUT we are not transforming before loading in our pipeline just yet.
#     We Extract and Load the raw JSON.

# %%
#json

import pandas as pd
import json

weather_hourly_df = pd.DataFrame(data)
weather_hourly_df['data'] = weather_hourly_df['extracted_data'].apply(lambda x: x['data'])
exploded_df = weather_hourly_df.explode('data')
normalized_data = pd.json_normalize(exploded_df['data'])
final_df = pd.concat([exploded_df.drop(columns=['data', 'extracted_data']).reset_index(drop=True), normalized_data], axis=1)
print(final_df)
final_df.info()
# Out:
#                    extracted_at airport_code  station_id                 time  \
# 0    2025-02-13 20:01:47.613777          MIA       72202  2017-09-01 00:00:00
# 1    2025-02-13 20:01:47.613777          MIA       72202  2017-09-01 01:00:00
# 2    2025-02-13 20:01:47.613777          MIA       72202  2017-09-01 02:00:00
# 3    2025-02-13 20:01:47.613777          MIA       72202  2017-09-01 03:00:00
# 4    2025-02-13 20:01:47.613777          MIA       72202  2017-09-01 04:00:00
# ...                         ...          ...         ...                  ...
# 2155 2025-02-13 20:01:48.951475          TPA       72211  2017-09-30 19:00:00
# 2156 2025-02-13 20:01:48.951475          TPA       72211  2017-09-30 20:00:00
# 2157 2025-02-13 20:01:48.951475          TPA       72211  2017-09-30 21:00:00
# 2158 2025-02-13 20:01:48.951475          TPA       72211  2017-09-30 22:00:00
# 2159 2025-02-13 20:01:48.951475          TPA       72211  2017-09-30 23:00:00
#
#       temp  dwpt  rhum  prcp  snow   wdir  wspd  wpgt    pres  tsun  coco
# 0     30.6  23.3  65.0   0.0  None  120.0  14.8  None  1015.5  None   NaN
# 1     30.0  24.4  72.0   0.0  None  140.0  11.2  None  1016.6  None   NaN
# 2     30.0  23.9  70.0   0.0  None  120.0  13.0  None  1017.1  None   NaN
# 3     29.4  23.8  72.0   0.0  None  120.0  13.0  None  1017.4  None   NaN
# 4     29.4  23.8  72.0   0.0  None  110.0  13.0  None  1017.0  None   NaN
# ...    ...   ...   ...   ...   ...    ...   ...   ...     ...   ...   ...
# 2155  30.0  22.2  63.0   0.0  None  250.0   9.4  None  1013.2  None   NaN
# 2156  28.9  23.3  72.0   0.0  None  240.0  16.6  None  1012.7  None   NaN
# 2157  28.3  22.3  70.0   NaN  None  340.0  16.6  None  1012.9  None   NaN
# 2158  27.2  21.7  72.0   0.0  None  340.0  13.0  None  1012.9  None   7.0
# 2159  26.1  22.8  82.0   0.8  None   10.0   0.0  None  1013.3  None   NaN
#
# [2160 rows x 15 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2160 entries, 0 to 2159
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   extracted_at  2160 non-null   datetime64[ns]
#  1   airport_code  2160 non-null   object
#  2   station_id    2160 non-null   int64
#  3   time          2160 non-null   object
#  4   temp          2132 non-null   float64
#  5   dwpt          2132 non-null   float64
#  6   rhum          2132 non-null   float64
#  7   prcp          2000 non-null   float64
#  8   snow          0 non-null      object
#  9   wdir          1891 non-null   float64
#  10  wspd          2132 non-null   float64
#  11  wpgt          0 non-null      object
#  12  pres          2130 non-null   float64
#  13  tsun          0 non-null      object
#  14  coco          209 non-null    float64
# dtypes: datetime64[ns](1), float64(8), int64(1), object(5)
# memory usage: 253.2+ KB

# %% [raw]
# data = weather_hourly_df
# weather_hourly_df = pd.DataFrame(data)
#
# normalized_df_weather_hourly = pd.json_normalize(
#     weather_hourly_df['extracted_data'],  # Column with nested JSON
#     record_path=['data'],  # Path to the list of records you want to normalize
#     meta=['meta'],  # Include metadata from the nested structure
#     meta_prefix='meta_'  # Prefix for metadata columns
# )
#
# result_df = pd.concat([weather_hourly_df.drop(columns=['extracted_data']), normalised_df], axis=1)
# print(result_df)
#
# # df = weather_hourly = pd.json_normalize(pd.json_normalize(weather_hourly_df['extracted_data']).loc[0, 'data'])

# %% [markdown]
# > #### Note: we only used up 9 more API calls

# %% [markdown]
# ### Loading the data into the DB

# %%
# getting API and DB credentials - Alternative 1: dotenv_values()

config = dotenv_values()
 
pg_user = config['POSTGRES_USER'] # align the key labels with your .env file
pg_host = config['POSTGRES_HOST']
pg_port = config['POSTGRES_PORT']
pg_db = config['POSTGRES_DB']
pg_schema = config['POSTGRES_SCHEMA']
pg_pass = config['POSTGRES_PASS']

# %%
# updating the url
url = f'postgresql://{pg_user}:{pg_pass}@{pg_host}:{pg_port}/{pg_db}'

# creating the engine
engine = create_engine(url, echo=False)

# %%
engine.url # checking the url (pass is hidden)
# Out:
# postgresql://martinvolman:***@data-analytics-course-2.c8g8r1deus2v.eu-central-1.rds.amazonaws.com:5432/hh_analytics_24_4

# %%
# defining data types for the DB
dtype_dict = {
    'extracted_at': types.DateTime,
    'airport_code': types.String,
    'station_id': types.Integer,
    'time': types.String,
    'temp': types.Float,
    'dwpt': types.Float,
    'rhum': types.Float,
    'prcp': types.Float,
    'snow': types.String,
    'wdir': types.Float,
    'wspd': types.Float,
    'wpgt': types.String,
    'pres': types.Float,
    'tsun': types.String,
    'coco': types.Float,
}

# dtype_dict = {
#     'extracted_at':types.DateTime,
#     'airport_code': types.String,
#     'station_id': types.Integer,
#     'extracted_data':postgres_json
#              }
#-------
# #pruebo aca
# import pandas as pd
# import json
# import psycopg2  # O el conector de tu base de datos

# def create_dataframe_from_json(json_string):
#     #"""Crea un DataFrame de Pandas desde una cadena JSON."""
#     try:
#         data = json.loads(json_string)['data']  # Accede directamente a 'data'
#         return pd.DataFrame(data)
#     except (json.JSONDecodeError, KeyError, TypeError) as e:
#         print(f"Error al procesar JSON: {e}")
#         return pd.DataFrame()  # Devuelve un DataFrame vacío en caso de error

# def create_table_and_insert(df, table_name, conn):
#     #"""Crea la tabla (si es necesario) e inserta los datos."""
#     if df.empty:
#         return  # No hay nada que hacer si el DataFrame está vacío

#     try:
#         # Usa Pandas para inferir tipos y crear/insertar
#         df.to_sql(table_name, conn, if_exists='replace', index=False, method='multi')  # Usa 'multi' para inserciones más rápidas
#         print(f"Datos insertados en '{table_name}' correctamente.")
#     except Exception as e:
#         print(f"Error al insertar datos: {e}")
#         conn.rollback()  # Importante: Rollback en caso de error

# Ejemplo (reemplaza con tus datos y conexión):
# extracted_data = '{"meta": ..., "data": [...]}' # Tu cadena JSON
# df = create_dataframe_from_json(extracted_data)

# if not df.empty:
#     conn = psycopg2.connect(...)  # Detalles de tu conexión a la base de datos
#     create_table_and_insert(df, "nombre_de_tu_tabla", conn)
#     conn.close()

# %%
# writing dataframe to DB
# weather_hourly_df.to_sql(name = 'weather_hourly_raw', 
final_df.to_sql(name = 'weather_hourly_cleaned', 
                       con = engine, 
                       schema = pg_schema, 
                       if_exists='replace', 
                       dtype=dtype_dict,
                       index=False
                      )
# Out:
# 160

# %% [markdown]
# If you see a '45' as the result of the last cell. Something went right again. :)
#
# Check in DBeaver if you see a new table called "weather_hourly_raw" in your Schema. Don't forget to refresh your Schema.

# %% [markdown]
# ## Done. We finished "Loading"! :)
