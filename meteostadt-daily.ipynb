# %% [markdown]
# # Extracting `DAILY` data from API and Loading it to DB

# %% [markdown]
# As the purpose of our pipeline is to make Weather Data available for comparison to flights and airports data, in the first step we need to load the weather data in a raw form (JSON) into our database. So in later steps we can transform it to meaningful and useful tables.

# %% [markdown]
# ### General Presteps:

# %% [markdown]
# The Goal of this Notebook is to get raw JSON data for Daily and Hourly Weather for 3 airport weather stations and load it as it is to our database.
# - Find Station IDs for **defined** airports
# - Define the start and end of the period
# - get the API Key from the `.env`

# %% [markdown]
# ### Imports

# %% [markdown]
# we will need the credentials we saved in the `.env` file. We also will need SQLAlchemy and its functions

# %%
# we will need the credentials we saved in the .env file
from dotenv import dotenv_values

# We also will need SQLAlchemy and its functions
from sqlalchemy import create_engine, types
from sqlalchemy.dialects.postgresql import JSON as postgres_json

import pandas as pd

# requests library will make the API calls. 
# the json package will parse the JSON string and convert it to Python data structures
import requests
import json

# with 'datetime' we want to catch the timestamp of the API call. For the actuality reference. 
# and 'time' for slowing down a .bit
from datetime import datetime
import time

# %% [markdown]
# ### Defining Airports andd finding the Station IDs

# %% [markdown]
# To find the Station IDs for the airpors without stressing our API Call limits, we will use the   search option of the **https://meteostat.net/**
#
# Search for the names of the airports above and find the Station IDs

# %%
#MIA,MCO,TPA
airport_staids = {
    'MIA': 72202,  
    'MCO': 72205,  # Arkansas / Little Rock
    # 'XNA': 'KXNA0'  # Fayetteville / Castleville
    'TPA': 72211 #Tulsa
    
}

# %% [markdown]
# ### Defining the period

# %% [markdown]
# Our flight Data is from 2024-01-01 until 2024-03-31. For the lectures we will use the same period for the meteostat JSON API.

# %%
period_start = "2017-08-30"
period_end = "2017-09-30"

# %% [markdown]
# ### loading API Key

# %%
# getting API and DB credentials - Alternative 1: dotenv_values()

config = dotenv_values()
api_key = config['X-RapidAPI_Key'] # align the key label with your .env file

# %% [markdown]
# # Part 1: Daily Station Data

# %% [markdown]
# ### Objectives -  Daily Station Data:

# %% [markdown]
# ### Test: For-loop generating the querystrings

# %%
# testing for-loop: querystring for each airport

for airport in airport_staids:
   
    querystring = {
        "station":airport_staids[airport]
        ,"start":period_start
        ,"end":period_end
        ,"model":"true"
    }
    print(airport, "\n", querystring)
# Out:
# MIA
#  {'station': 72202, 'start': '2017-08-30', 'end': '2017-09-30', 'model': 'true'}
# MCO
#  {'station': 72205, 'start': '2017-08-30', 'end': '2017-09-30', 'model': 'true'}
# TPA
#  {'station': 72211, 'start': '2017-08-30', 'end': '2017-09-30', 'model': 'true'}

# %% [markdown]
# **[what is the 'model' parameter?](https://dev.meteostat.net/api/stations/daily.html#parameters)**
# -> Substitute missing records with statistically optimized model data

# %% [markdown]
# ### API CALL daily (per station)

# %%
#  let's catch each response in a dictionary. create an empty dictionary with the following keys:

weather_dict = {'extracted_at':[], 
                'airport_code':[], 
                'station_id':[], 
                'extracted_data':[]
               }

# API CALL daily (station) - for the syntax: see the rapidapi interface

url = "https://meteostat.p.rapidapi.com/stations/daily"

headers = {                   #headers dictionary is use to send specific information as part of the HTTPS request
        "X-RapidAPI-Key": api_key,
        "X-RapidAPI-Host": "meteostat.p.rapidapi.com"
}

# for-loop for the querystrings
for airport in airport_staids:
   
    querystring = {
        "station":airport_staids[airport]
        ,"start":period_start
        ,"end":period_end
        ,"model":"true"
    }
    
    # making one call with the current querystring
    response = requests.get(url, headers=headers, params=querystring)  #This argument is where you pass additional parameters to the API in the form of a dictionary 
                
    # appending data to the dictionary:
    weather_dict['extracted_at'].append(datetime.now())                # timestamp, 
    weather_dict['airport_code'].append(airport)                       # airport code    
    weather_dict['station_id'].append(airport_staids[airport])         # weater Station ID
    weather_dict['extracted_data'].append(json.loads(response.text))   # JSON string

# %% [markdown]
# #### Checkout the filled dictionary

# %%
weather_dict
# Out:
# {'extracted_at': [datetime.datetime(2025, 2, 13, 22, 48, 48, 867412),
#   datetime.datetime(2025, 2, 13, 22, 48, 49, 523166),
#   datetime.datetime(2025, 2, 13, 22, 48, 49, 821475)],
#  'airport_code': ['MIA', 'MCO', 'TPA'],
#  'station_id': [72202, 72205, 72211],
#  'extracted_data': [{'meta': {'generated': '2025-02-12 16:36:14'},
#    'data': [{'date': '2017-08-30 00:00:00',
#      'tavg': 30.6,
#      'tmin': 27.2,
#      'tmax': 34.4,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': 9.7,
#      'wpgt': None,
#      'pres': 1015.8,
#      'tsun': 562},
#     {'date': '2017-08-31 00:00:00',
#      'tavg': 31.1,
#      'tmin': 28.9,
#      'tmax': 33.9,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 112.0,
#      'wspd': 14.0,
#      'wpgt': None,
#      'pres': 1016.7,
#      'tsun': 487},
#     {'date': '2017-09-01 00:00:00',
#      'tavg': 30.9,
#      'tmin': 26.1,
#      'tmax': 33.9,
#      'prcp': 11.4,
#      'snow': None,
#      'wdir': 117.0,
#      'wspd': 12.2,
#      'wpgt': None,
#      'pres': 1016.5,
#      'tsun': 309},
#     {'date': '2017-09-02 00:00:00',
#      'tavg': 28.1,
#      'tmin': 23.3,
#      'tmax': 31.1,
#      'prcp': 26.2,
#      'snow': None,
#      'wdir': None,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1017.6,
#      'tsun': 81},
#     {'date': '2017-09-03 00:00:00',
#      'tavg': 29.4,
#      'tmin': 26.7,
#      'tmax': 33.9,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': 7.2,
#      'wpgt': None,
#      'pres': 1017.9,
#      'tsun': 165},
#     {'date': '2017-09-04 00:00:00',
#      'tavg': 29.2,
#      'tmin': 26.1,
#      'tmax': 33.3,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 64.0,
#      'wspd': 15.1,
#      'wpgt': None,
#      'pres': 1016.7,
#      'tsun': 158},
#     {'date': '2017-09-05 00:00:00',
#      'tavg': 30.0,
#      'tmin': 26.1,
#      'tmax': 33.9,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 101.0,
#      'wspd': 12.2,
#      'wpgt': None,
#      'pres': 1014.8,
#      'tsun': 344},
#     {'date': '2017-09-06 00:00:00',
#      'tavg': 29.6,
#      'tmin': 27.8,
#      'tmax': 32.8,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': 8.6,
#      'wpgt': None,
#      'pres': 1013.5,
#      'tsun': 98},
#     {'date': '2017-09-07 00:00:00',
#      'tavg': 30.4,
#      'tmin': 27.2,
#      'tmax': 34.4,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 105.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1014.0,
#      'tsun': 374},
#     {'date': '2017-09-08 00:00:00',
#      'tavg': 31.2,
#      'tmin': 28.9,
#      'tmax': 34.4,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 45.0,
#      'wspd': 19.4,
#      'wpgt': None,
#      'pres': 1011.5,
#      'tsun': None},
#     {'date': '2017-09-09 00:00:00',
#      'tavg': 29.2,
#      'tmin': 25.0,
#      'tmax': 31.1,
#      'prcp': 45.2,
#      'snow': None,
#      'wdir': 64.0,
#      'wspd': 31.3,
#      'wpgt': None,
#      'pres': 1005.2,
#      'tsun': None},
#     {'date': '2017-09-10 00:00:00',
#      'tavg': 26.3,
#      'tmin': 24.4,
#      'tmax': 28.3,
#      'prcp': 131.6,
#      'snow': None,
#      'wdir': None,
#      'wspd': 61.9,
#      'wpgt': None,
#      'pres': 995.0,
#      'tsun': None},
#     {'date': '2017-09-11 00:00:00',
#      'tavg': 31.8,
#      'tmin': 27.8,
#      'tmax': 32.2,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': None,
#      'wpgt': None,
#      'pres': 1004.9,
#      'tsun': 226},
#     {'date': '2017-09-12 00:00:00',
#      'tavg': 29.3,
#      'tmin': 26.1,
#      'tmax': 33.3,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 238.0,
#      'wspd': 8.6,
#      'wpgt': None,
#      'pres': 1011.2,
#      'tsun': 414},
#     {'date': '2017-09-13 00:00:00',
#      'tavg': 29.3,
#      'tmin': 27.2,
#      'tmax': 32.8,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': 7.9,
#      'wpgt': None,
#      'pres': 1013.6,
#      'tsun': 180},
#     {'date': '2017-09-14 00:00:00',
#      'tavg': 29.5,
#      'tmin': 26.7,
#      'tmax': 33.3,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': 8.6,
#      'wpgt': None,
#      'pres': 1014.6,
#      'tsun': 224},
#     {'date': '2017-09-15 00:00:00',
#      'tavg': 29.6,
#      'tmin': 27.2,
#      'tmax': 33.3,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 53.0,
#      'wspd': 11.5,
#      'wpgt': None,
#      'pres': 1014.8,
#      'tsun': 315},
#     {'date': '2017-09-16 00:00:00',
#      'tavg': 30.0,
#      'tmin': 27.2,
#      'tmax': 33.3,
#      'prcp': 0.3,
#      'snow': None,
#      'wdir': 28.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1014.5,
#      'tsun': 240},
#     {'date': '2017-09-17 00:00:00',
#      'tavg': 29.6,
#      'tmin': 26.7,
#      'tmax': 33.3,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 336.0,
#      'wspd': 10.8,
#      'wpgt': None,
#      'pres': 1014.1,
#      'tsun': 214},
#     {'date': '2017-09-18 00:00:00',
#      'tavg': 29.1,
#      'tmin': 25.6,
#      'tmax': 32.8,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 321.0,
#      'wspd': 8.3,
#      'wpgt': None,
#      'pres': 1013.2,
#      'tsun': 325},
#     {'date': '2017-09-19 00:00:00',
#      'tavg': 29.7,
#      'tmin': 26.7,
#      'tmax': 34.4,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 267.0,
#      'wspd': 9.0,
#      'wpgt': None,
#      'pres': 1013.0,
#      'tsun': 217},
#     {'date': '2017-09-20 00:00:00',
#      'tavg': 29.4,
#      'tmin': 25.6,
#      'tmax': 32.8,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': 8.3,
#      'wpgt': None,
#      'pres': 1014.5,
#      'tsun': 50},
#     {'date': '2017-09-21 00:00:00',
#      'tavg': 29.0,
#      'tmin': 23.3,
#      'tmax': 33.3,
#      'prcp': 58.2,
#      'snow': None,
#      'wdir': None,
#      'wspd': 7.2,
#      'wpgt': None,
#      'pres': 1013.6,
#      'tsun': 63},
#     {'date': '2017-09-22 00:00:00',
#      'tavg': 27.6,
#      'tmin': 24.4,
#      'tmax': 31.1,
#      'prcp': 55.1,
#      'snow': None,
#      'wdir': 6.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1011.8,
#      'tsun': 16},
#     {'date': '2017-09-23 00:00:00',
#      'tavg': 28.1,
#      'tmin': 25.0,
#      'tmax': 32.8,
#      'prcp': 10.9,
#      'snow': None,
#      'wdir': 23.0,
#      'wspd': 7.9,
#      'wpgt': None,
#      'pres': 1010.0,
#      'tsun': 96},
#     {'date': '2017-09-24 00:00:00',
#      'tavg': 29.1,
#      'tmin': 26.7,
#      'tmax': 32.8,
#      'prcp': 0.3,
#      'snow': None,
#      'wdir': None,
#      'wspd': 6.1,
#      'wpgt': None,
#      'pres': 1010.7,
#      'tsun': 99},
#     {'date': '2017-09-25 00:00:00',
#      'tavg': 29.3,
#      'tmin': 27.2,
#      'tmax': 32.2,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': 6.1,
#      'wpgt': None,
#      'pres': 1011.5,
#      'tsun': 28},
#     {'date': '2017-09-26 00:00:00',
#      'tavg': 28.2,
#      'tmin': 24.4,
#      'tmax': 31.1,
#      'prcp': 8.1,
#      'snow': None,
#      'wdir': None,
#      'wspd': 8.3,
#      'wpgt': None,
#      'pres': 1012.3,
#      'tsun': None},
#     {'date': '2017-09-27 00:00:00',
#      'tavg': 28.4,
#      'tmin': 26.7,
#      'tmax': 31.7,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': 5.0,
#      'wpgt': None,
#      'pres': 1012.2,
#      'tsun': None},
#     {'date': '2017-09-28 00:00:00',
#      'tavg': 28.6,
#      'tmin': 25.6,
#      'tmax': 32.2,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 130.0,
#      'wspd': 10.1,
#      'wpgt': None,
#      'pres': 1012.2,
#      'tsun': None},
#     {'date': '2017-09-29 00:00:00',
#      'tavg': 27.0,
#      'tmin': 24.4,
#      'tmax': 29.4,
#      'prcp': 33.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1012.9,
#      'tsun': None},
#     {'date': '2017-09-30 00:00:00',
#      'tavg': 27.8,
#      'tmin': 25.0,
#      'tmax': 32.2,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': None,
#      'wspd': 7.9,
#      'wpgt': None,
#      'pres': 1013.7,
#      'tsun': None}]},
#   {'meta': {'generated': '2025-02-12 16:36:14'},
#    'data': [{'date': '2017-08-30 00:00:00',
#      'tavg': 27.2,
#      'tmin': 22.2,
#      'tmax': 33.9,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': None,
#      'wspd': 4.0,
#      'wpgt': None,
#      'pres': 1016.0,
#      'tsun': None},
#     {'date': '2017-08-31 00:00:00',
#      'tavg': 28.8,
#      'tmin': 22.8,
#      'tmax': 34.4,
#      'prcp': 3.8,
#      'snow': 0.0,
#      'wdir': 130.0,
#      'wspd': 10.8,
#      'wpgt': None,
#      'pres': 1016.8,
#      'tsun': None},
#     {'date': '2017-09-01 00:00:00',
#      'tavg': 27.7,
#      'tmin': 22.8,
#      'tmax': 34.4,
#      'prcp': 10.4,
#      'snow': 0.0,
#      'wdir': 156.0,
#      'wspd': 11.5,
#      'wpgt': None,
#      'pres': 1016.7,
#      'tsun': None},
#     {'date': '2017-09-02 00:00:00',
#      'tavg': 25.9,
#      'tmin': 22.2,
#      'tmax': 31.7,
#      'prcp': 0.8,
#      'snow': 0.0,
#      'wdir': None,
#      'wspd': 6.1,
#      'wpgt': None,
#      'pres': 1017.5,
#      'tsun': None},
#     {'date': '2017-09-03 00:00:00',
#      'tavg': 25.4,
#      'tmin': 23.3,
#      'tmax': 30.0,
#      'prcp': 14.7,
#      'snow': 0.0,
#      'wdir': None,
#      'wspd': 5.8,
#      'wpgt': None,
#      'pres': 1018.5,
#      'tsun': None},
#     {'date': '2017-09-04 00:00:00',
#      'tavg': 26.8,
#      'tmin': 23.3,
#      'tmax': 32.8,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': None,
#      'wspd': 5.0,
#      'wpgt': None,
#      'pres': 1017.7,
#      'tsun': None},
#     {'date': '2017-09-05 00:00:00',
#      'tavg': 26.8,
#      'tmin': 23.3,
#      'tmax': 32.2,
#      'prcp': 15.5,
#      'snow': 0.0,
#      'wdir': None,
#      'wspd': 4.3,
#      'wpgt': None,
#      'pres': 1015.5,
#      'tsun': None},
#     {'date': '2017-09-06 00:00:00',
#      'tavg': 25.8,
#      'tmin': 23.3,
#      'tmax': 29.4,
#      'prcp': 33.0,
#      'snow': 0.0,
#      'wdir': None,
#      'wspd': 4.3,
#      'wpgt': None,
#      'pres': 1013.9,
#      'tsun': None},
#     {'date': '2017-09-07 00:00:00',
#      'tavg': 27.2,
#      'tmin': 23.3,
#      'tmax': 33.3,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': None,
#      'wspd': 10.4,
#      'wpgt': None,
#      'pres': 1014.9,
#      'tsun': None},
#     {'date': '2017-09-08 00:00:00',
#      'tavg': 26.7,
#      'tmin': 24.4,
#      'tmax': 31.7,
#      'prcp': 13.5,
#      'snow': 0.0,
#      'wdir': 29.0,
#      'wspd': 16.9,
#      'wpgt': None,
#      'pres': 1014.7,
#      'tsun': None},
#     {'date': '2017-09-09 00:00:00',
#      'tavg': 25.4,
#      'tmin': 24.4,
#      'tmax': 28.9,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 34.0,
#      'wspd': 24.8,
#      'wpgt': None,
#      'pres': 1011.5,
#      'tsun': None},
#     {'date': '2017-09-10 00:00:00',
#      'tavg': 24.9,
#      'tmin': 22.2,
#      'tmax': 26.1,
#      'prcp': 167.9,
#      'snow': 0.0,
#      'wdir': 59.0,
#      'wspd': 36.7,
#      'wpgt': None,
#      'pres': None,
#      'tsun': None},
#     {'date': '2017-09-11 00:00:00',
#      'tavg': 25.6,
#      'tmin': 22.2,
#      'tmax': 28.9,
#      'prcp': 15.5,
#      'snow': 0.0,
#      'wdir': 185.0,
#      'wspd': 40.7,
#      'wpgt': None,
#      'pres': None,
#      'tsun': None},
#     {'date': '2017-09-12 00:00:00',
#      'tavg': 25.5,
#      'tmin': 21.7,
#      'tmax': 31.1,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 235.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1010.3,
#      'tsun': None},
#     {'date': '2017-09-13 00:00:00',
#      'tavg': 26.5,
#      'tmin': 21.1,
#      'tmax': 31.7,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': None,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1013.5,
#      'tsun': None},
#     {'date': '2017-09-14 00:00:00',
#      'tavg': 27.6,
#      'tmin': 21.7,
#      'tmax': 33.3,
#      'prcp': 64.5,
#      'snow': 0.0,
#      'wdir': None,
#      'wspd': 6.1,
#      'wpgt': None,
#      'pres': 1014.7,
#      'tsun': None},
#     {'date': '2017-09-15 00:00:00',
#      'tavg': 26.2,
#      'tmin': 22.8,
#      'tmax': 32.8,
#      'prcp': 0.3,
#      'snow': 0.0,
#      'wdir': None,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1015.8,
#      'tsun': None},
#     {'date': '2017-09-16 00:00:00',
#      'tavg': 27.4,
#      'tmin': 23.9,
#      'tmax': 32.2,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 39.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1016.1,
#      'tsun': None},
#     {'date': '2017-09-17 00:00:00',
#      'tavg': 26.6,
#      'tmin': 23.3,
#      'tmax': 31.7,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 353.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1015.2,
#      'tsun': None},
#     {'date': '2017-09-18 00:00:00',
#      'tavg': 25.4,
#      'tmin': 22.8,
#      'tmax': 30.0,
#      'prcp': 0.5,
#      'snow': 0.0,
#      'wdir': 4.0,
#      'wspd': 16.2,
#      'wpgt': None,
#      'pres': 1014.2,
#      'tsun': None},
#     {'date': '2017-09-19 00:00:00',
#      'tavg': 25.9,
#      'tmin': 23.3,
#      'tmax': 30.0,
#      'prcp': 1.5,
#      'snow': 0.0,
#      'wdir': 36.0,
#      'wspd': 11.5,
#      'wpgt': None,
#      'pres': 1014.5,
#      'tsun': None},
#     {'date': '2017-09-20 00:00:00',
#      'tavg': 26.8,
#      'tmin': 21.7,
#      'tmax': 32.2,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': None,
#      'wspd': 10.1,
#      'wpgt': None,
#      'pres': 1015.6,
#      'tsun': None},
#     {'date': '2017-09-21 00:00:00',
#      'tavg': 26.3,
#      'tmin': 22.2,
#      'tmax': 31.1,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 36.0,
#      'wspd': 12.2,
#      'wpgt': None,
#      'pres': 1015.1,
#      'tsun': None},
#     {'date': '2017-09-22 00:00:00',
#      'tavg': 25.8,
#      'tmin': 22.2,
#      'tmax': 31.7,
#      'prcp': 5.6,
#      'snow': 0.0,
#      'wdir': 26.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1013.3,
#      'tsun': None},
#     {'date': '2017-09-23 00:00:00',
#      'tavg': 25.8,
#      'tmin': 23.3,
#      'tmax': 31.1,
#      'prcp': 3.0,
#      'snow': 0.0,
#      'wdir': 31.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1012.1,
#      'tsun': None},
#     {'date': '2017-09-24 00:00:00',
#      'tavg': 26.6,
#      'tmin': 23.3,
#      'tmax': 31.7,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 26.0,
#      'wspd': 14.0,
#      'wpgt': None,
#      'pres': 1011.9,
#      'tsun': None},
#     {'date': '2017-09-25 00:00:00',
#      'tavg': 27.2,
#      'tmin': 23.3,
#      'tmax': 32.8,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 352.0,
#      'wspd': 9.0,
#      'wpgt': None,
#      'pres': 1011.6,
#      'tsun': None},
#     {'date': '2017-09-26 00:00:00',
#      'tavg': 27.4,
#      'tmin': 23.3,
#      'tmax': 32.8,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': None,
#      'wspd': 8.3,
#      'wpgt': None,
#      'pres': 1012.1,
#      'tsun': None},
#     {'date': '2017-09-27 00:00:00',
#      'tavg': 27.7,
#      'tmin': 23.9,
#      'tmax': 33.3,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 54.0,
#      'wspd': 6.8,
#      'wpgt': None,
#      'pres': 1012.0,
#      'tsun': None},
#     {'date': '2017-09-28 00:00:00',
#      'tavg': 27.5,
#      'tmin': 22.8,
#      'tmax': 32.8,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': None,
#      'wspd': 7.9,
#      'wpgt': None,
#      'pres': 1012.6,
#      'tsun': None},
#     {'date': '2017-09-29 00:00:00',
#      'tavg': 26.6,
#      'tmin': 23.3,
#      'tmax': 31.7,
#      'prcp': 0.3,
#      'snow': 0.0,
#      'wdir': None,
#      'wspd': 9.0,
#      'wpgt': None,
#      'pres': 1013.4,
#      'tsun': None},
#     {'date': '2017-09-30 00:00:00',
#      'tavg': 25.8,
#      'tmin': 22.8,
#      'tmax': 31.1,
#      'prcp': 10.9,
#      'snow': 0.0,
#      'wdir': 287.0,
#      'wspd': 10.8,
#      'wpgt': None,
#      'pres': 1012.8,
#      'tsun': None}]},
#   {'meta': {'generated': '2025-02-12 16:36:15'},
#    'data': [{'date': '2017-08-30 00:00:00',
#      'tavg': 27.4,
#      'tmin': 24.4,
#      'tmax': 32.8,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': None,
#      'wspd': 6.1,
#      'wpgt': None,
#      'pres': 1016.0,
#      'tsun': None},
#     {'date': '2017-08-31 00:00:00',
#      'tavg': 29.9,
#      'tmin': 27.2,
#      'tmax': 34.4,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': None,
#      'wspd': 8.3,
#      'wpgt': None,
#      'pres': 1016.7,
#      'tsun': None},
#     {'date': '2017-09-01 00:00:00',
#      'tavg': 29.1,
#      'tmin': 23.9,
#      'tmax': 33.9,
#      'prcp': 23.1,
#      'snow': 0.0,
#      'wdir': 140.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1016.7,
#      'tsun': None},
#     {'date': '2017-09-02 00:00:00',
#      'tavg': 25.8,
#      'tmin': 23.9,
#      'tmax': 30.6,
#      'prcp': 7.1,
#      'snow': 0.0,
#      'wdir': None,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1017.6,
#      'tsun': None},
#     {'date': '2017-09-03 00:00:00',
#      'tavg': 27.2,
#      'tmin': 25.0,
#      'tmax': 30.6,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': None,
#      'wspd': 5.8,
#      'wpgt': None,
#      'pres': 1018.4,
#      'tsun': None},
#     {'date': '2017-09-04 00:00:00',
#      'tavg': 28.4,
#      'tmin': 25.0,
#      'tmax': 32.8,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': None,
#      'wspd': 6.8,
#      'wpgt': None,
#      'pres': 1017.5,
#      'tsun': None},
#     {'date': '2017-09-05 00:00:00',
#      'tavg': 28.7,
#      'tmin': 26.1,
#      'tmax': 32.2,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': None,
#      'wspd': 6.5,
#      'wpgt': None,
#      'pres': 1015.5,
#      'tsun': None},
#     {'date': '2017-09-06 00:00:00',
#      'tavg': 27.8,
#      'tmin': 26.1,
#      'tmax': 30.6,
#      'prcp': 1.3,
#      'snow': 0.0,
#      'wdir': None,
#      'wspd': 4.7,
#      'wpgt': None,
#      'pres': 1013.9,
#      'tsun': None},
#     {'date': '2017-09-07 00:00:00',
#      'tavg': 28.9,
#      'tmin': 25.0,
#      'tmax': 33.9,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': None,
#      'wspd': 7.9,
#      'wpgt': None,
#      'pres': 1014.8,
#      'tsun': None},
#     {'date': '2017-09-08 00:00:00',
#      'tavg': 28.6,
#      'tmin': 25.6,
#      'tmax': 34.4,
#      'prcp': 0.3,
#      'snow': 0.0,
#      'wdir': 45.0,
#      'wspd': 12.2,
#      'wpgt': None,
#      'pres': None,
#      'tsun': None},
#     {'date': '2017-09-09 00:00:00',
#      'tavg': 28.2,
#      'tmin': 25.6,
#      'tmax': 33.3,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 37.0,
#      'wspd': 19.8,
#      'wpgt': None,
#      'pres': 1011.0,
#      'tsun': None},
#     {'date': '2017-09-10 00:00:00',
#      'tavg': 25.8,
#      'tmin': 23.3,
#      'tmax': 27.2,
#      'prcp': 107.7,
#      'snow': 0.0,
#      'wdir': 30.0,
#      'wspd': 32.8,
#      'wpgt': None,
#      'pres': 1001.9,
#      'tsun': None},
#     {'date': '2017-09-11 00:00:00',
#      'tavg': 24.6,
#      'tmin': 22.8,
#      'tmax': 27.8,
#      'prcp': 8.4,
#      'snow': 0.0,
#      'wdir': 255.0,
#      'wspd': 30.2,
#      'wpgt': None,
#      'pres': None,
#      'tsun': None},
#     {'date': '2017-09-12 00:00:00',
#      'tavg': 26.7,
#      'tmin': 24.4,
#      'tmax': 30.0,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 254.0,
#      'wspd': 11.5,
#      'wpgt': None,
#      'pres': 1010.5,
#      'tsun': None},
#     {'date': '2017-09-13 00:00:00',
#      'tavg': 26.7,
#      'tmin': 22.8,
#      'tmax': 31.1,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': None,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1013.6,
#      'tsun': None},
#     {'date': '2017-09-14 00:00:00',
#      'tavg': 27.7,
#      'tmin': 25.0,
#      'tmax': 32.2,
#      'prcp': 16.3,
#      'snow': 0.0,
#      'wdir': None,
#      'wspd': 5.8,
#      'wpgt': None,
#      'pres': 1014.8,
#      'tsun': None},
#     {'date': '2017-09-15 00:00:00',
#      'tavg': 27.7,
#      'tmin': 25.0,
#      'tmax': 33.9,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': None,
#      'wspd': 6.5,
#      'wpgt': None,
#      'pres': 1015.6,
#      'tsun': None},
#     {'date': '2017-09-16 00:00:00',
#      'tavg': 29.1,
#      'tmin': 25.6,
#      'tmax': 34.4,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 43.0,
#      'wspd': 9.0,
#      'wpgt': None,
#      'pres': 1016.1,
#      'tsun': None},
#     {'date': '2017-09-17 00:00:00',
#      'tavg': 28.7,
#      'tmin': 24.4,
#      'tmax': 32.8,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 357.0,
#      'wspd': 10.8,
#      'wpgt': None,
#      'pres': 1015.8,
#      'tsun': None},
#     {'date': '2017-09-18 00:00:00',
#      'tavg': 27.8,
#      'tmin': 23.3,
#      'tmax': 32.8,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 356.0,
#      'wspd': 12.2,
#      'wpgt': None,
#      'pres': 1014.7,
#      'tsun': None},
#     {'date': '2017-09-19 00:00:00',
#      'tavg': 27.9,
#      'tmin': 23.3,
#      'tmax': 33.9,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 34.0,
#      'wspd': 9.0,
#      'wpgt': None,
#      'pres': 1014.5,
#      'tsun': None},
#     {'date': '2017-09-20 00:00:00',
#      'tavg': 29.0,
#      'tmin': 23.9,
#      'tmax': 34.4,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': None,
#      'wspd': 8.6,
#      'wpgt': None,
#      'pres': 1015.4,
#      'tsun': None},
#     {'date': '2017-09-21 00:00:00',
#      'tavg': 28.9,
#      'tmin': 24.4,
#      'tmax': 33.9,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 66.0,
#      'wspd': 7.9,
#      'wpgt': None,
#      'pres': 1014.9,
#      'tsun': None},
#     {'date': '2017-09-22 00:00:00',
#      'tavg': 28.3,
#      'tmin': 23.9,
#      'tmax': 33.9,
#      'prcp': 1.3,
#      'snow': 0.0,
#      'wdir': 38.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1013.3,
#      'tsun': None},
#     {'date': '2017-09-23 00:00:00',
#      'tavg': 27.9,
#      'tmin': 24.4,
#      'tmax': 34.4,
#      'prcp': 2.3,
#      'snow': 0.0,
#      'wdir': 52.0,
#      'wspd': 10.8,
#      'wpgt': None,
#      'pres': 1012.1,
#      'tsun': None},
#     {'date': '2017-09-24 00:00:00',
#      'tavg': 27.1,
#      'tmin': 24.4,
#      'tmax': 32.8,
#      'prcp': 0.8,
#      'snow': 0.0,
#      'wdir': 36.0,
#      'wspd': 8.6,
#      'wpgt': None,
#      'pres': 1012.0,
#      'tsun': None},
#     {'date': '2017-09-25 00:00:00',
#      'tavg': 28.1,
#      'tmin': 25.6,
#      'tmax': 32.8,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 351.0,
#      'wspd': 8.6,
#      'wpgt': None,
#      'pres': 1012.0,
#      'tsun': None},
#     {'date': '2017-09-26 00:00:00',
#      'tavg': 28.4,
#      'tmin': 25.0,
#      'tmax': 32.8,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': None,
#      'wspd': 6.1,
#      'wpgt': None,
#      'pres': 1012.3,
#      'tsun': None},
#     {'date': '2017-09-27 00:00:00',
#      'tavg': 28.9,
#      'tmin': 24.4,
#      'tmax': 33.3,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 331.0,
#      'wspd': 10.1,
#      'wpgt': None,
#      'pres': 1012.1,
#      'tsun': None},
#     {'date': '2017-09-28 00:00:00',
#      'tavg': 29.1,
#      'tmin': 25.6,
#      'tmax': 33.9,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': None,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1012.4,
#      'tsun': None},
#     {'date': '2017-09-29 00:00:00',
#      'tavg': 28.8,
#      'tmin': 25.0,
#      'tmax': 32.8,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': None,
#      'wspd': 6.1,
#      'wpgt': None,
#      'pres': 1013.3,
#      'tsun': None},
#     {'date': '2017-09-30 00:00:00',
#      'tavg': 26.8,
#      'tmin': 25.0,
#      'tmax': 31.1,
#      'prcp': 0.8,
#      'snow': 0.0,
#      'wdir': None,
#      'wspd': 7.9,
#      'wpgt': None,
#      'pres': 1013.7,
#      'tsun': None}]}]}

# %% [markdown]
# ### Make it a dataframe

# %% [markdown]
# this is our raw data, which we now can load into the database

# %%
weather_daily_df = pd.DataFrame(weather_dict)
weather_daily_df
data = weather_daily_df

# %% [markdown]
# ### SIDEBAR: For the curious and sceptics...

# %% [markdown]
#     In case you can't resist to know what the data looks like when flattened.
#     Here is the preview with pandas. BUT we are not transforming before loading in our pipeline just yet.
#     We Extract and Load the raw JSON.

# %%
#json

import pandas as pd
import json


weather_daily_df = pd.DataFrame(data)
weather_daily_df['data'] = weather_daily_df['extracted_data'].apply(lambda x: x['data']) 
exploded_df = weather_daily_df.explode('data')
normalized_data = pd.json_normalize(exploded_df['data'])
final_df = pd.concat([exploded_df.drop(columns=['data', 'extracted_data']).reset_index(drop=True), normalized_data], axis=1)
print(final_df)
final_df.info()
# Out:
#                  extracted_at airport_code  station_id                 date  \
# 0  2025-02-13 22:48:48.867412          MIA       72202  2017-08-30 00:00:00
# 1  2025-02-13 22:48:48.867412          MIA       72202  2017-08-31 00:00:00
# 2  2025-02-13 22:48:48.867412          MIA       72202  2017-09-01 00:00:00
# 3  2025-02-13 22:48:48.867412          MIA       72202  2017-09-02 00:00:00
# 4  2025-02-13 22:48:48.867412          MIA       72202  2017-09-03 00:00:00
# ..                        ...          ...         ...                  ...
# 91 2025-02-13 22:48:49.821475          TPA       72211  2017-09-26 00:00:00
# 92 2025-02-13 22:48:49.821475          TPA       72211  2017-09-27 00:00:00
# 93 2025-02-13 22:48:49.821475          TPA       72211  2017-09-28 00:00:00
# 94 2025-02-13 22:48:49.821475          TPA       72211  2017-09-29 00:00:00
# 95 2025-02-13 22:48:49.821475          TPA       72211  2017-09-30 00:00:00
#
#     tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres   tsun
# 0   30.6  27.2  34.4   0.0   NaN    NaN   9.7  None  1015.8  562.0
# 1   31.1  28.9  33.9   0.0   NaN  112.0  14.0  None  1016.7  487.0
# 2   30.9  26.1  33.9  11.4   NaN  117.0  12.2  None  1016.5  309.0
# 3   28.1  23.3  31.1  26.2   NaN    NaN   7.6  None  1017.6   81.0
# 4   29.4  26.7  33.9   0.0   NaN    NaN   7.2  None  1017.9  165.0
# ..   ...   ...   ...   ...   ...    ...   ...   ...     ...    ...
# 91  28.4  25.0  32.8   0.0   0.0    NaN   6.1  None  1012.3    NaN
# 92  28.9  24.4  33.3   0.0   0.0  331.0  10.1  None  1012.1    NaN
# 93  29.1  25.6  33.9   0.0   0.0    NaN   7.6  None  1012.4    NaN
# 94  28.8  25.0  32.8   0.0   0.0    NaN   6.1  None  1013.3    NaN
# 95  26.8  25.0  31.1   0.8   0.0    NaN   7.9  None  1013.7    NaN
#
# [96 rows x 14 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   extracted_at  96 non-null     datetime64[ns]
#  1   airport_code  96 non-null     object
#  2   station_id    96 non-null     int64
#  3   date          96 non-null     object
#  4   tavg          96 non-null     float64
#  5   tmin          96 non-null     float64
#  6   tmax          96 non-null     float64
#  7   prcp          96 non-null     float64
#  8   snow          64 non-null     float64
#  9   wdir          50 non-null     float64
#  10  wspd          95 non-null     float64
#  11  wpgt          0 non-null      object
#  12  pres          92 non-null     float64
#  13  tsun          24 non-null     float64
# dtypes: datetime64[ns](1), float64(9), int64(1), object(3)
# memory usage: 10.6+ KB

# %% [raw]
# # using pd.json_normalize() twice to get to the weather_stats of one airport under 'data'
#
# df_JFK = pd.json_normalize(pd.json_normalize(weather_daily_df['extracted_data']).loc[0, 'data'])
# df_JFK

# %% [raw]
# #  compare if needed to the JSON for 'JFK', first row
# weather_daily_df.loc[0,'extracted_data']

# %% [markdown]
# > #### Note: we only used up 3 API calls per attempt

# %% [raw]
# #trying json_normalize
# import pandas as pd
#
# #Normalizar los datos de cada aeropuerto en un diccionario de DataFrames
# dfs = {airport: pd.json_normalize(data) for airport, data in weather_daily_df['extracted_data'].items()}

# %% [markdown]
# ### Loading the data into the DB

# %% [markdown]
# Now all we need to create a table in your Schema in our database is part of the `weather_daily_df` dataframe.
# We can use pandas' ability to work with SQLAlchemy and "save" the data to the DB using the `.to_sql()` method

# %%
# getting API and DB credentials - Alternative 1: dotenv_values()

config = dotenv_values()
 
pg_user = config['POSTGRES_USER'] # align the key labels with your .env file
pg_host = config['POSTGRES_HOST']
pg_port = config['POSTGRES_PORT']
pg_db = config['POSTGRES_DB']
pg_schema = config['POSTGRES_SCHEMA']
pg_pass = config['POSTGRES_PASS']

# %%
pg_schema
# Out:
# 's_martinvolman'

# %%
# updating the url
url = f'postgresql://{pg_user}:{pg_pass}@{pg_host}:{pg_port}/{pg_db}'

# creating the engine
engine = create_engine(url, echo=False)

# %%
engine.url # checking the url (pass is hidden)
# Out:
# postgresql://martinvolman:***@data-analytics-course-2.c8g8r1deus2v.eu-central-1.rds.amazonaws.com:5432/hh_analytics_24_4

# %%
# defining data types for the DB

dtype_dict = {
    'extracted_at': types.DateTime,
    'airport_code': types.String,
    'station_id': types.Integer,
    'time': types.String,
    'temp': types.Float,
    'dwpt': types.Float,
    'rhum': types.Float,
    'prcp': types.Float,
    'snow': types.String,
    'wdir': types.Float,
    'wspd': types.Float,
    'wpgt': types.String,
    'pres': types.Float,
    'tsun': types.String,
    'coco': types.Float,
}

# %%
# #check if the dataframe is empty
# for airport, df in dfs.items():
#     print(f"Checking DataFrame for {airport}:")
#     print(df.shape)  # Check row and column count
#     print(df.head())  # Check the first few rows

#     if df.shape[0] == 0:
#         print(f"⚠️ The DataFrame for {airport} is empty, skipping insert.")
#         continue  # Skip if the DataFrame is empty
    
#     # If the DataFrame is not empty, proceed to insert into the DB
#     table_name = f"weather_daily_raw_{str(airport).lower()}"
#     df.to_sql(name=table_name, 
#               con=engine, 
#               schema=pg_schema, 
#               if_exists='replace',  
#               dtype=dtype_dict, 
#               index=False)

#     print(f"✅ Data for {airport} written to {table_name}")
# Out:
# Checking DataFrame for 0:
# (1, 2)
#                                                 data       meta.generated
# 0  [{'date': '2017-08-30 00:00:00', 'tavg': 30.6,...  2025-02-12 16:36:14
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File /usr/local/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#
# File /usr/local/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/sqlalchemy/engine/default.py:942, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     941 def do_execute(self, cursor, statement, parameters, context=None):
# --> 942     cursor.execute(statement, parameters)
#
# ProgrammingError: can't adapt type 'dict'
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[20], line 13
#      11 # If the DataFrame is not empty, proceed to insert into the DB
#      12 table_name = f"weather_daily_raw_{str(airport).lower()}"
# ---> 13 df.to_sql(name=table_name,
#      14           con=engine,
#      15           schema=pg_schema,
#      16           if_exists='replace',
#      17           dtype=dtype_dict,
#      18           index=False)
#      20 print(f"✅ Data for {airport} written to {table_name}")
#
# File /usr/local/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File /usr/local/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/pandas/core/generic.py:3087, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2889 """
#    2890 Write records stored in a DataFrame to a SQL database.
#    2891
#    (...)
#    3083 [(1,), (None,), (2,)]
#    3084 """  # noqa: E501
#    3085 from pandas.io import sql
# -> 3087 return sql.to_sql(
#    3088     self,
#    3089     name,
#    3090     con,
#    3091     schema=schema,
#    3092     if_exists=if_exists,
#    3093     index=index,
#    3094     index_label=index_label,
#    3095     chunksize=chunksize,
#    3096     dtype=dtype,
#    3097     method=method,
#    3098 )
#
# File /usr/local/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/pandas/io/sql.py:842, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     837     raise NotImplementedError(
#     838         "'frame' argument should be either a Series or a DataFrame"
#     839     )
#     841 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 842     return pandas_sql.to_sql(
#     843         frame,
#     844         name,
#     845         if_exists=if_exists,
#     846         index=index,
#     847         index_label=index_label,
#     848         schema=schema,
#     849         chunksize=chunksize,
#     850         dtype=dtype,
#     851         method=method,
#     852         engine=engine,
#     853         **engine_kwargs,
#     854     )
#
# File /usr/local/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/pandas/io/sql.py:2018, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2006 sql_engine = get_engine(engine)
#    2008 table = self.prep_table(
#    2009     frame=frame,
#    2010     name=name,
#    (...)
#    2015     dtype=dtype,
#    2016 )
# -> 2018 total_inserted = sql_engine.insert_records(
#    2019     table=table,
#    2020     con=self.con,
#    2021     frame=frame,
#    2022     name=name,
#    2023     index=index,
#    2024     schema=schema,
#    2025     chunksize=chunksize,
#    2026     method=method,
#    2027     **engine_kwargs,
#    2028 )
#    2030 self.check_case_sensitive(name=name, schema=schema)
#    2031 return total_inserted
#
# File /usr/local/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/pandas/io/sql.py:1567, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1565 if re.search(msg, err_text):
#    1566     raise ValueError("inf cannot be used with MySQL") from err
# -> 1567 raise err
#
# File /usr/local/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/pandas/io/sql.py:1558, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1555 from sqlalchemy import exc
#    1557 try:
# -> 1558     return table.insert(chunksize=chunksize, method=method)
#    1559 except exc.StatementError as err:
#    1560     # GH34431
#    1561     # https://stackoverflow.com/a/67358288/6067848
#    1562     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1563     )|inf can not be used with MySQL"""
#
# File /usr/local/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/pandas/io/sql.py:1119, in SQLTable.insert(self, chunksize, method)
#    1116     break
#    1118 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1119 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1120 # GH 46891
#    1121 if num_inserted is not None:
#
# File /usr/local/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/pandas/io/sql.py:1010, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     998 """
#     999 Execute SQL statement inserting data
#    1000
#    (...)
#    1007    Each item contains a list of values to be inserted
#    1008 """
#    1009 data = [dict(zip(keys, row)) for row in data_iter]
# -> 1010 result = conn.execute(self.table.insert(), data)
#    1011 return result.rowcount
#
# File /usr/local/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1416, in Connection.execute(self, statement, parameters, execution_options)
#    1414     raise exc.ObjectNotExecutableError(statement) from err
#    1415 else:
# -> 1416     return meth(
#    1417         self,
#    1418         distilled_parameters,
#    1419         execution_options or NO_OPTIONS,
#    1420     )
#
# File /usr/local/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/sqlalchemy/sql/elements.py:515, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     513     if TYPE_CHECKING:
#     514         assert isinstance(self, Executable)
# --> 515     return connection._execute_clauseelement(
#     516         self, distilled_params, execution_options
#     517     )
#     518 else:
#     519     raise exc.ObjectNotExecutableError(self)
#
# File /usr/local/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1638, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1626 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1627     "compiled_cache", self.engine._compiled_cache
#    1628 )
#    1630 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1631     dialect=dialect,
#    1632     compiled_cache=compiled_cache,
#    (...)
#    1636     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1637 )
# -> 1638 ret = self._execute_context(
#    1639     dialect,
#    1640     dialect.execution_ctx_cls._init_compiled,
#    1641     compiled_sql,
#    1642     distilled_parameters,
#    1643     execution_options,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     elem,
#    1647     extracted_params,
#    1648     cache_hit=cache_hit,
#    1649 )
#    1650 if has_events:
#    1651     self.dispatch.after_execute(
#    1652         self,
#    1653         elem,
#    (...)
#    1657         ret,
#    1658     )
#
# File /usr/local/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1843, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1841     return self._exec_insertmany_context(dialect, context)
#    1842 else:
# -> 1843     return self._exec_single_context(
#    1844         dialect, context, statement, parameters
#    1845     )
#
# File /usr/local/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1983, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1980     result = context._setup_result_proxy()
#    1982 except BaseException as e:
# -> 1983     self._handle_dbapi_exception(
#    1984         e, str_statement, effective_parameters, cursor, context
#    1985     )
#    1987 return result
#
# File /usr/local/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/sqlalchemy/engine/base.py:2352, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2350 elif should_wrap:
#    2351     assert sqlalchemy_exception is not None
# -> 2352     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2353 else:
#    2354     assert exc_info[1] is not None
#
# File /usr/local/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1962                 break
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#    1969     self.dispatch.after_cursor_execute(
#    1970         self,
#    1971         cursor,
#    (...)
#    1975         context.executemany,
#    1976     )
#
# File /usr/local/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/sqlalchemy/engine/default.py:942, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     941 def do_execute(self, cursor, statement, parameters, context=None):
# --> 942     cursor.execute(statement, parameters)
#
# ProgrammingError: (psycopg2.ProgrammingError) can't adapt type 'dict'
# [SQL: INSERT INTO s_martinvolman.weather_daily_raw_0 (data, "meta.generated") VALUES (%(data)s, %(meta_generated)s)]
# [parameters: {'data': [{'date': '2017-08-30 00:00:00', 'tavg': 30.6, 'tmin': 27.2, 'tmax': 34.4, 'prcp': 0.0, 'snow': None, 'wdir': None, 'wspd': 9.7, 'wpgt': None, 'pres': ... (5233 characters truncated) ... 0:00:00', 'tavg': 27.8, 'tmin': 25.0, 'tmax': 32.2, 'prcp': 0.0, 'snow': None, 'wdir': None, 'wspd': 7.9, 'wpgt': None, 'pres': 1013.7, 'tsun': None}], 'meta_generated': '2025-02-12 16:36:14'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# #1 option with json
# # Assuming 'data' is a column with a list of dictionaries
# for airport, df in dfs.items():
#     # Flatten the 'data' column if it's a list of dictionaries
#     if isinstance(df['data'].iloc[0], list):
#         # If 'data' is a list of dictionaries, normalize it
#         df_data_normalized = pd.json_normalize(df['data'].explode())
#         df = pd.concat([df.drop(columns=['data']), df_data_normalized], axis=1)
    
#     # Generate table name
#     table_name = f"weather_daily_raw_{str(airport).lower()}"
    
#     # Write to SQL
#     df.to_sql(name=table_name, 
#               con=engine, 
#               schema=pg_schema, 
#               if_exists='replace',  
#               dtype=dtype_dict, 
#               index=False)

#     print(f"✅ Data for {airport} written to {table_name}")
# Out:
# ✅ Data for 0 written to weather_daily_raw_0
# ✅ Data for 1 written to weather_daily_raw_1
# ✅ Data for 2 written to weather_daily_raw_2

# %%
final_df.to_sql(name = 'weather_daily_cleaned', 
                       con = engine, 
                       schema = pg_schema, 
                       if_exists='replace', 
                       dtype=dtype_dict,
                       index=False
                      )
# Out:
# 96

# %% [markdown]
# If you see a '3' as the result of the last cell. Something should be right. :)
#
# Check in DBeaver if you see a new table in your Schema. Don't forget to refresh your Schema.

# %% [markdown]
# ## Now continue with the hourly data.
